# %% [markdown]
# # Analysis of the Datapoints Dataframe
#
# ## Imports and reading

# %%
import pandas as pd
from pathlib import Path
from utils.utils import print_pretty_df

# Quick ANSI color code shortcuts
r = "\033[31m"
y = "\033[33m"
g = "\033[32m"
b = "\033[34m"
e = "\033[0m"

pickleName = "all_datapoints.pkl"
datapointsDfPath = Path("..") / "data" / "Dataframes" / pickleName
datapointsDf = pd.read_pickle(datapointsDfPath)

# %%
# print(len(datapointsDf))
# print(len(datapointsDf[datapointsDf["Task"].isin(["Classification", "Object detection"])]))
print_pretty_df(datapointsDf)
# Out:
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+
# |    |                   BBT Citation Key                    |             Model             | Equivalent model |    Backbone    |    Modality    |                      Dataset                      |         Task         |               Application               |                     Board                      |    Implementation    | Publication year |  Latency  |    FPS     | Task score  | Footprint |  Throughput  | Power consumption | Frequency  | Complexity  |               Design                |     Memory     |                Precision                |                        Optimizations                        |                 FPGA Util                 | DPU Config | DPU Core | DPU Util |  DPU Optimizations  |
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+
# | 0  |          vitoloRealTimeOnboardSatellite2024           |              CNN              |       CNN        |                |      RGB       |        Landsat-8 (cust.) {Classification}         |    Classification    |             Cloud coverage              |              Artix-7 (XC7A35T) {}              |  RTL design (VHDL)   |       2024       |           |            |  89.64% F1  |           |  1.14 GOP/s  |      0.116 W      |   36 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                Original                 |                      ['Multiple PEs']                       | Low (N/A DSP, N/A BRAM, 38% LUT, 15% FF)  |            |          |          |         []          |
# | 1  |                 kimOnOrbitAICloud2024                 |      TriCloudNet + U-Net      |       CNN        |   SqueezeNet   |      RGB       |        Landsat-8 (cust.) {Classification}         |    Classification    |             Cloud coverage              |           Zynq 7000 (Z7020) {ZC702}            |     HLS (Vivado)     |       2024       |  1028 ms  |  0.97 FPS  |  6.84% CRE  |  3.61 MB  |              |      0.196 W      |            |             |           Model Specific            |    Off-chip    |                   N/A                   |                      ['Multiple PEs']                       |     High (49% DSP, 60% BRAM, 70% LUT)     |            |          |          |         []          |
# | 2  |         nguyenFPGASoCImplementationYOLOv42024         |            YOLOv4             |      YOLOv4      |   Darknet53    |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2024       | 107.94 ms |  17.9 FPS  |  83.7% mAP  |  245 MB   |              |      30.1 W       |  100 MHz   |  105.9G OP  |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 3  |         nguyenFPGASoCImplementationYOLOv42024         |        YOLOv4-tiny 3L         |      YOLOv4      | Darknet53-tiny |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2024       | 19.18 ms  |  125 FPS   | 72.24% mAP  | 24.10 MB  |              |      26.40 W      |  100 MHz   |  15.32G OP  |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 4  |        yahiaouiParallelizationFuzzyARTMAP2017a        |           BRAM_DSP            |   Fuzzy ARTMAP   |                | RGB + infrared |      ALSAT-2A (cust.) {Pixel classification}      | Pixel classification |           Landcover/Land use            |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |       2017       | 21.28 us  |            |  94.8% OA   |           |              |       4.8W        |  192 MHz   |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                      ['Multiple PEs']                       |          Low (91% DSP,52% BRAM)           |            |          |          |         []          |
# | 5  |        yahiaouiParallelizationFuzzyARTMAP2017a        |            LUT_MUL            |   Fuzzy ARTMAP   |                | RGB + infrared |      ALSAT-2A (cust.) {Pixel classification}      | Pixel classification |           Landcover/Land use            |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |       2017       | 21.28 us  |            |  94.8% OA   |           |              |       4.5W        |  189 MHz   |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                      ['Multiple PEs']                       |           Low (0% DSP,0% BRAM)            |            |          |          |         []          |
# | 6  |       weiFPGABasedHybridTypeImplementation2019        |          LeNet-5 f32          |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |       2019       |  2.29 ms  |            |  98.76% OA  |  6.64 MB  |              |                   |  100 MHz   |             |           Various Kernels           |    Off-chip    |               Float (32)                |                      ['Multiple PEs']                       |        Average (34% DSP, 33% BRAM)        |            |          |          |         []          |
# | 7  |       weiFPGABasedHybridTypeImplementation2019        |          LeNet-5 i8           |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |       2019       |  2.29 ms  |            |  97.77% OA  |  1.66 MB  |              |                   |  100 MHz   |             |           Various Kernels           |    Off-chip    |                Fixed (8)                |                      ['Multiple PEs']                       |          Low (14% DSP, 16% BRAM)          |            |          |          |         []          |
# | 8  |            fraczekEmbeddedVisionSystem2018            |         Decision Tree         |        ML        |                |      RGB       |      UAV RGB (cust.) {Pixel classification}       | Pixel classification |  Safe UAV landing site identification   |         Zynq 7000 (XC7Z020) {Arty Z7}          | RTL design (Verilog) |       2018       |  300 ms*  |            |  92.1% OA   |           |              |      3.50 W       |            |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                           ['N/A']                           |          Low (10% DSP, 86% BRAM)          |            |          |          |         []          |
# | 9  |                heConfigurable2D3D2023a                |            2D CNN             |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 0.097 ms* |            |  98.24% OA  |  1.20 MB  |  7.07 GOP/s  |      8.40 W       |  100 MHz   |  0.684M OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |         Low (22.5% DSP, 71% BRAM)         |            |          |          |         []          |
# | 10 |                heConfigurable2D3D2023a                |            3D CNN             |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 1.11 ms*  |            |  94.09% OA  |  0.12 MB  |  3.81 GOP/s  |      8.40 W       |  100 MHz   |  4.231M OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |         Low (27.9% DSP, 76% BRAM)         |            |          |          |         []          |
# | 11 |                heConfigurable2D3D2023a                |           HybridSN            |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 7.71 ms*  |            |   100% OA   | 20.50 MB  | 13.18 GOP/s  |      8.40 W       |  100 MHz   | 101.642M OP |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |        Average (37% DSP, 80% BRAM)        |            |          |          |         []          |
# | 12 |       hammoudArtificialNeuralNetworksBased2022a       |              MLP              |       MLP        |                |      SAR       |              SAR (sim.) {Regression}              |      Regression      |      Oil spills feature extraction      |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         N/A          |       2022       |           |            |             |           |              |      0.13 W       |            |             | Model Specific (All layers on FPGA) |    On-chip     |                Original                 |                           ['N/A']                           |          Low (26% DSP, 1% BRAM)           |            |          |          |         []          |
# | 13 |       matos-carvalhoStaticDynamicAlgorithms2019       |              MLP              |       MLP        |                |      RGB       |         UAV RGB (cust.) {Classification}          |    Classification    |           Landcover/Land use            | Spartan-3A (XC3SD1800A) {Avnet Spartan-3A DSP} |  RTL design (VHDL)   |       2019       |           |            |  95.14% OA  |           |              |                   |            |             |         Algorithm Specific          |    On-chip     |      Mixed width (Fixed 32 and 8)       |                           ['N/A']                           |          Low (26% DSP, N/A BRAM)          |            |          |          |         []          |
# | 14 |          hashimotoShipClassificationSAR2019a          |              CNN              |       CNN        |                |      SAR       |          ALOS-2 (cust.) {Classification}          |    Classification    |           Ship identification           |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         FINN         |       2019       |  330 ms   |            |   100% OA   |           |              |                   |            |             |                 N/A                 |    On-chip     |                 Binary                  |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 15 |           shibiOnboardTargetDetection2021a            |             LPDBL             |        ML        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |       2021       |           |            |             |           |              |                   |  200 MHz   |             |         Algorithm Specific          |    On-chip     |                Original                 |                      ['Multiple PEs']                       |          Low (14% DSP, 15% BRAM)          |            |          |          |         []          |
# | 16 |              liNovelCNNBasedAP2DNet2020               |           AP2D-Net            |       CNN        |                |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |                 Diverse                 |          Zynq US+ (XCZU3EG) {Ultra96}          |   RTL design (N/A)   |       2020       |  32.8 ms  | 30.53 FPS  | 55.0% mIoU  |           | 130.20 GOP/s |      5.59 W       |  300 MHz   |             |           Various Kernels           |    Off-chip    | Mixed (Fixed (1 to 24) weights (3) act) |                        ['SIMD MVU']                         |         High (80% DSP, 75% BRAM)          |            |          |          |         []          |
# | 17 |            bahlLowpowerNeuralNetworks2019a            |            C-FCN++            |       CNN        |                |      RGB       |              38-Cloud {Segmentation}              |     Segmentation     |             Cloud coverage              |             Cyclone V (5CSXC6) {}              |      HLS (VGT)       |       2019       |  150 ms   |   7 FPS    | 79.30% mIoU | 0.047 MB  |              |                   |  100 MHz   |   4.7K OP   | Model Specific (All layers on FPGA) |    On-chip     |               Fixed (16)                |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 18 |             boyleHighlevelFPGADesign2023a             |      Deep Belief Network      |       RBM        |                |      HSI       |    Airport-Beach-Urban {Pixel classification}     | Pixel classification |            Anomaly detection            |          Zynq US+ (XCZU7EV) {ZCU104}           |     HLS (Vitis)      |       2023       |  5.4 ms   |            |             |           |              |                   |  250 MHz   |             |         Algorithm Specific          |    On-chip     |               Float (32)                |                           ['N/A']                           |          Low (10% DSP, 0% BRAM)           |            |          |          |         []          |
# | 19 |      chenHardwareImplementationConvolutional2020      |            LeNet-5            |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |             Kintex-7 (XC7K325T) {}             |         N/A          |       2020       |  2.29 ms  |            |  98.18% OA  |           |              |                   |  100 MHz   |             |           Model Specific            |    Off-chip    |               Float (32)                |                           ['N/A']                           |          Low (N/A DSP, 33% BRAM)          |            |          |          |         []          |
# | 20 |        zhaoHardwareAccelerationSatellite2023a         |      YOLOv4-MobileNetv3       |      YOLOv4      |  MobileNetv3   |      RGB       |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |            Zynq US+ (XCK26) {KV260}            |   Vitis AI (v2.5)    |       2023       |           | 48.14 FPS  | 82.61% mAP  |  5.69 MB  |              |      7.20 W       |  200 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |        Average (59% DSP, N/A BRAM)        |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 21 |         chellaswamyFPGAbasedRemoteTarget2024          |            SAM-GNN            |       GNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |       2024       |           |            |  95.05% OA  |           |              |                   |  200 MHz   |             |         Algorithm Specific          |    Off-chip    |                Original                 |                      ['Multiple PEs']                       |          Low (13% DSP, 14% BRAM)          |            |          |          |         []          |
# | 22 |         nerisFPGABasedImplementationCNN2022a          |          AlexNetLite          |     AlexNet      |    AlexNet     |      RGB       |              MASATI {Classification}              |    Classification    |           Ship identification           |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |       2022       |           |            |   89% F1    |           |              |                   |  200 MHz   |  5.71G OP   |                 N/A                 |      N/A       |               Fixed (16)                |                           ['N/A']                           |          Low (31% DSP,39% BRAM)           |            |          |          |         []          |
# | 23 |         nerisFPGABasedImplementationCNN2022a          |        MobileNetv1Lite        |       CNN        |  MobileNetv1   |      RGB       |              MASATI {Classification}              |    Classification    |           Ship identification           |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |       2022       |           |            |   94% F1    |           |              |                   |  200 MHz   |  0.05G OP   |                 N/A                 |      N/A       |               Fixed (16)                |                           ['N/A']                           |          Low (31% DSP,39% BRAM)           |            |          |          |         []          |
# | 24 |         zhangFPGAImplementationCNNbased2021a          |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z035) {}             |  RTL design (VHDL)   |       2021       |  3400 ms  |            | 67.32% mAP  |           | 111.50 GOP/s |      5.96 W       |  200 MHz   |   379G OP   |           Various Kernels           |    Off-chip    |      Mixed (Fixed 8 and Float 32)       |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (21% DSP, 74% BRAM)          |            |          |          |         []          |
# | 25 |             wangFastDetectionObstacle2024             |        Lightweight CNN        |       CNN        |   ResNet-18    |   RGB + MMW    |      UAV RGB+MMW (cust.) {Object Detection}       |   Object detection   |         UAV obstacles detection         |             Zynq 7000 (XC7Z020) {}             |         N/A          |       2024       |           |  60.0 FPS  |  70.1% mAP  |           |              |      3.30 W       |  100 MHz   |   4.6G OP   |                 N/A                 |    Off-chip    |                Fixed (8)                |                           ['N/A']                           |         High (70% DSP, 25% BRAM)          |            |          |          |         []          |
# | 26 |            liEfficientObjectDetection2019a            |           CBFF-SSD            |       SSD        |  MobileNetv1   |      RGB       |          NWPU VHR-10 {Object Detection}           |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z100) {}             | RTL design (Verilog) |       2019       | 42.59 ms  |            | 91.42% mAP  |           | 452.80 GOP/s |      19.52 W      |  200 MHz   |             |           Various Kernels           |    Off-chip    |               Fixed (16)                |            ['Advanced Dataflow', 'Multiple PEs']            |        Average (57% DSP, 60% BRAM)        |            |          |          |         []          |
# | 27 |               liEdgeRealtimeObject2023a               |           RFA-YOLO            |      YOLOv4      |   MobileNeXt   |      RGB       |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2023       |           | 27.97 FPS  | 64.85% mAP  | 24.75 MB  |              |      15.82 W      |  200 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 28 |            myojinDetectingUncertainBNN2020            |              BNN              |       CNN        |                |      SAR       |          ALOS-2 (cust.) {Classification}          |    Classification    |           Ship identification           |          Zynq 7000 (XC7Z045) {ZC706}           |         FINN         |       2020       | 21.14 ms  |            |             |           |              |                   |            |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 29 |           wuDesignImplementationRemote2021            |        Improved YOLOv3        |      YOLOv3      |   DarkNet53    |      RGB       | Google Earth Studio RGB (sim.) {Object Detection} |   Object detection   |           Aircraft detection            |             Zynq US+ (XCZU9EG) {}              |      HLS (N/A)       |       2021       |   7 ms    |            |   92% OA    |  8.50 MB  |              |                   |            |             |           Various Kernels           |    Off-chip    |                Fixed (8)                |                      ['Multiple PEs']                       |                    N/A                    |            |          |          |         []          |
# | 30 |       upadhyayDesignImplementationCNNbased2024        |           ResNet-50           |       CNN        |   ResNet-50    |      RGB       |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |       2024       |  10.7 ms  | 93.02 FPS  |             |           |              |                   |            |             |                                     |                |                Fixed (8)                |                             []                              |                                           |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 31 |       upadhyayDesignImplementationCNNbased2024        |            SICNet             |       CNN        |                |      RGB       |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |       2024       |  1.8 ms   | 530.66 FPS |  85.76% OA  |           |              |                   |            |             |                                     |                |                Fixed (8)                |                             []                              |                                           |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 32 |          torresCombinedWeightlessNeural2020           |   Weightless Neural Systems   |       WNS        |                |      RGB       |      UAV RGB (cust.) {Pixel classification}       | Pixel classification |         Deforestation detection         |             Zynq 7000 (XC7Z020) {}             |         N/A          |       2020       |           |            |  90.0% OA   |           |              |                   |            |             |                 N/A                 |    On-chip     |                Original                 |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 33 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |       CloudSatNet-1 Q2        |       CNN        |                |      RGB       |             L8 Biome {Classification}             |    Classification    |             Cloud coverage              |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       2022       |           | 15.46 FPS  |  83.41% OA  |  1.43 MB  |              |      2.52 W       |  100 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                      ['Multiple PEs']                       |               Low (14% DSP)               |            |          |          |         []          |
# | 34 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |       CloudSatNet-1 Q4        |       CNN        |                |      RGB       |             L8 Biome {Classification}             |    Classification    |             Cloud coverage              |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       2022       |           | 15.47 FPS  |  87.42% OA  |  3.06 MB  |              |      2.59 W       |  100 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                Fixed (4)                |                      ['Multiple PEs']                       |               Low (14% DSP)               |            |          |          |         []          |
# | 35 |       yanAutomaticDeploymentConvolutional2022a        |        Improved VGG16         |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |       2022       |  1780 ms  |            |  88.08% OA  | 14.80 MB  | 23.06 GOP/s  |      3.41 W       |  200 MHz   |  40.96G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (12% DSP, 29% BRAM)          |            |          |          |         []          |
# | 36 |       yanAutomaticDeploymentConvolutional2022a        |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |       2022       | 17120 ms  |            | 67.30% mAP  | 49.40 MB  | 22.17 GOP/s  |      3.41 W       |  200 MHz   | 379.55G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (12% DSP, 29% BRAM)          |            |          |          |         []          |
# | 37 |             yuImprovedLightweightDeep2024             |     Improved YOLOv4-tiny      |   YOLOv4-tiny    |  CSPDarknet53  |      RGB       |    FastenerDataset (cust.) {Object Detection}     |   Object detection   | Railway track fastener defect detection |          Zynq US+ (XCZU7EV) {ZCU104}           |   Vitis AI (v1.4)    |       2024       |           | 295.9 FPS  |  95.1% mAP  |           |              |      20.00 W      |  300 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |    2     |   N/A    |    ['UltraRAM']     |
# | 38 |       rapuanoFPGAbasedHardwareAccelerator2021a        |          CloudScout           |       CNN        |                |      HSI       |        Sentinel-2 (cust.) {Classification}        |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU7EV) {ZCU106}           |  RTL design (VHDL)   |       2021       | 141.7 ms  |            |  92.0% OA   | 13.30 MB  |              |      3.40 W       | 115.4 MHz  |             |           Model Specific            |    Off-chip    |              Mixed (Fixed)              |            ['Advanced Dataflow', 'Multiple PEs']            |       High (67% DSP, 46% BRAM+URAM)       |            |          |          |         []          |
# | 39 |         zhangExtremelyPipelinedFPGAbased2023a         |             A2NN              |       CNN        |     VGG11      |      RGB       |        UC-Merced Land Use {Classification}        |    Classification    |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |   RTL design (N/A)   |       2023       |  4.92 ms  | 203.25 FPS |  94.76% OA  |           |  3047 GOP/s  |      8.27 W       |  200 MHz   |  14.99G OP  |           Model Specific            |    On-chip     |      Mixed (Fixed 4 and Float 32)       |                      ['Multiple PEs']                       |          Low (9% DSP, 86% BRAM)           |            |          |          |         []          |
# | 40 |        ieracitanoExplainableEmbeddedNeural2024        |          HO-ShipNet           |       CNN        |                |      RGB       |            Kaggle SSI {Classification}            |    Classification    |           Ship identification           |          Zynq 7000 (XC7Z045) {ZC706}           |  RTL design (VHDL)   |       2024       |  1.01 ms  |            |  93.44% F1  |           |              |      1.90 W       |            |             |           Model Specific            |    Off-chip    |               Fixed (16)                |                           ['N/A']                           |        Average (44% DSP, 44% BRAM)        |            |          |          |         []          |
# | 41 |       zhangEfficientFPGABasedImplementation2020       |            Q-IORN             |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          |  RTL design (VHDL)   |       2020       | 147.62 ms |  6.77 FPS  |  88.31% OA  | 121.51 MB | 209.60 GOP/s |      6.32 W       |  200 MHz   |             |           Model Specific            |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (21% DSP, 27% BRAM)          |            |          |          |         []          |
# | 42 |              huangEdgeTrustworthyAI2024               |             ETAUS             |       CNN        |   ResNet-50    |      HSI       |         UAV RGB (cust.) {Classification}          |    Classification    |         Air Quality Monitoring          |          Zynq US+ (XCZU19EG) {KV260}           |    Vitis AI (N/A)    |       2024       | 107.8 ms  |  9.3 FPS   |  86.38% F1  |           | 329.90 GOP/s |      1.65 W       | 106.25 MHz |  329.9G OP  |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 43 |           yangAlgorithmHardwareCodesign2022           |           CNN2@0.7            |      YOLOv2      |  MobileNetv1   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  0.7 ms   |  652 FPS   |   94% AP    |  0.09 MB  |  298 GOP/s   |      5.80 W       |  250 MHz   |  0.45G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (64% DSP,21% BRAM)         |            |          |          |         []          |
# | 44 |           yangAlgorithmHardwareCodesign2022           |           CNN4@0.7            |      YOLOv2      |  MobileNetv2   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  0.7 ms   |  636 FPS   |  93.3% AP   |  0.11 MB  |  366 GOP/s   |      6.60 W       |  250 MHz   |  0.56G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (69% DSP,21% BRAM)         |            |          |          |         []          |
# | 45 |           yangAlgorithmHardwareCodesign2022           |           CNN6@1.6            |      YOLOv2      |   SqueezeNet   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  1.6 ms   |  384 FPS   |  92.8% AP   |  0.09 MB  |  235 GOP/s   |      5.10 W       |  250 MHz   |   0.6G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (76% DSP,18% BRAM)         |            |          |          |         []          |
# | 46 |         niAlgorithmHardwareCoOptimization2023         |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       | 981.4 ms  |            | 67.30% mAP  | 49.40 MB  |  387 GOP/s   |      14.97 W      |  200 MHz   | 379.55G OP  |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 47 |         niAlgorithmHardwareCoOptimization2023         |           ResNet-34           |       CNN        |   ResNet-34    |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       |  40.2 ms  |            |  92.81% OA  | 21.29 MB  |  182 GOP/s   |      14.97 W      |  200 MHz   |  7.33G OP   |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 48 |         niAlgorithmHardwareCoOptimization2023         |             VGG16             |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       |  89.1 ms  |            |  91.90% OA  | 14.70 MB  |  344 GOP/s   |      14.97 W      |  200 MHz   |  30.69G OP  |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 49 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 0.25x           |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           | 34.18 FPS  |  76.2% mAP  |           |  138 GOP/s   |      2.40 W       |  200 MHz   |  4.04G OP   |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |            (73% DSP, 47% BRAM)            |            |          |          |         []          |
# | 50 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 0.5x            |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           |  9.6 FPS   |  83.9% mAP  |           |  150 GOP/s   |      2.60 W       |  200 MHz   |  15.65G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |         High (73% DSP, 55% BRAM)          |            |          |          |         []          |
# | 51 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 1.0x            |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           |  2.56 FPS  |  88.4% mAP  |           |  158 GOP/s   |      2.00 W       |  200 MHz   |  61.60G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |                                           |            |          |          |         []          |
# | 52 |         zhangAccurateLowlatencyEfficient2022a         |              GNN              |       GNN        |                |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Zynq US+ (XCZU7EV) {ZCU104}           |      HLS (N/A)       |       2022       | 0.105 ms  |  9500 FPS  |  99.09% OA  |  0.96 MB  |              |      6.30 W       |  125 MHz   |  2.13M OP   |           Various Kernels           |    On-chip     |               Float (32)                |   ['Advanced Dataflow', 'Multiple PEs', 'PEs Pipelined']    |       High (74% DSP, 91% BRAM+URAM)       |            |          |          |         []          |
# | 53 |          gargAircraftDetectionSatellite2024           |       ResNet-18+YOLOv2        |      YOLOv2      |   ResNet-18    |      RGB       |             Airbus {Object Detection}             |   Object detection   |           Aircraft detection            |          Zynq US+ (XCZU9EG) {ZCU102}           |     HLS (MATLAB)     |       2024       |           |   46 FPS   |   91% AP    |           |              |                   |  250 MHz   |             |           Model Specific            |    Off-chip    |                Fixed (8)                |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 54 |    wangAccelerationImplementationConvolutional2019    |              CNN              |       CNN        |                |      RGB       |            DAC 2018 {Object Detection}            |   Object detection   |                 Diverse                 |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |     HLS (Vivado)     |       2019       |           |   7 FPS    |  21% mIoU   |           | 69.80 GOP/s  |      2.38 W       |            |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                      ['Multiple PEs']                       |         Low (11% DSP, 100% BRAM)          |            |          |          |         []          |
# | 55 |           zhangAcceleratingGNNbasedSAR2023            |              GNN              |       GNN        |                |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |                Alveo (U280) {}                 |      HLS (N/A)       |       2023       |   27 ms   |  759 FPS   |             |           |  400 GOP/s   |      38.00 W      |  260 MHz   |             |           Various Kernels           | Off-chip (HBM) |                Original                 |         ['Multiple PEs', 'Other Kernel Splitting']          |        Average (43% DSP, 37% BRAM)        |            |          |          |         []          |
# | 56 |              gyaneshwarRealtimeSCSUP2022              |           CAG-SC2S            |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.27 us*  |            |  98.30% OA  |           |              |      0.31 W       | 70.40 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |         High (93% DSP, 21% BRAM))         |            |          |          |         []          |
# | 57 |              gyaneshwarRealtimeSCSUP2022              |           CAL-SC2S            |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.70 us*  |            |  99.69% OA  |           |              |      0.36 W       | 65.20 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |         High (96% DSP, 25% BRAM))         |            |          |          |         []          |
# | 58 |              gyaneshwarRealtimeSCSUP2022              |              SVM              |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.12 us*  |            |  20.71% OA  |           |              |      0.22 W       | 72.40 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |        Average (49% DSP, 6% BRAM))        |            |          |          |         []          |
# | 59 |          martinsRealtimeSVMbasedHardware2024          |              SVM              |        ML        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |             Zynq 7000 (XC7Z020) {}             |  RTL design (VHDL)   |       2024       | 0.11 ms*  |            |  82.48% AA  |           |              |                   |  200 MHz   |             |           Model Specific            |    On-chip     |                Original                 |                       ['Unclear/Bad']                       |        Average (38% DSP, N/A BRAM)        |            |          |          |         []          |
# | 60 |      sabogalMethodologyEvaluatingAnalyzing2021a       |             ENet              |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  25.2 FPS  | 63.3% mIoU  |  0.36 MB  |              |      3.36 W       |  300 MHz   |  4.06G OP   |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 61 |      sabogalMethodologyEvaluatingAnalyzing2021a       |            ESPNet             |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  11.7 FPS  | 55.5% mIoU  |  0.33 MB  |              |      3.08 W       |  300 MHz   |  3.71G OP   |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 62 |      sabogalMethodologyEvaluatingAnalyzing2021a       |              FPN              |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  14.1 FPS  | 65.3% mIoU  |  5.84 MB  |              |      4.03 W       |  300 MHz   |  17.30G OP  |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 63 |      sabogalMethodologyEvaluatingAnalyzing2021a       |             U-Net             |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  2.7 FPS   | 61.4% mIoU  |  7.40 MB  |              |      3.38 W       |  300 MHz   |  96.68G OP  |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 64 |          yangLightweightDetectionMethod2023           |          Ghost-YOLOS          |      YOLOv3      |    GhostNet    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z020) {}             | RTL design (Verilog) |       2023       |  320 ms   |            | 62.58% mAP  | 12.60 MB  | 29.53 GOP/s  |      2.98 W       |  150 MHz   |  8.41G OP   |           Model Specific            |    Off-chip    |               Fixed (16)                |               ['Multiple PEs', 'Unclear/Bad']               |        Average (58% DSP, 60% BRAM)        |            |          |          |         []          |
# | 65 |             ratnakumarHighSpeedRoller2021             | Roller Dung Bettle Clustering |        ML        |                |      RGB       |       Landsat-8-OLI (cust.) {Segmentation}        |     Segmentation     |                 General                 |            Virtex-6 (XC6VLX240T) {}            | RTL design (Verilog) |       2021       |  28.9 ms  |            | 37.45% SSIM |           |              |      0.12 W       | 230.52 MHz |   O(n) OP   |         Algorithm Specific          |    On-chip     |                   N/A                   |                    ['Advanced Dataflow']                    | Low (N/A DSP, 41% total slices, N/A BRAM) |            |          |          |         []          |
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+

# %% [markdown]
# ## Quick statistics / Overview

# %% [markdown]
# ### Implementation means
#
# Typical implementation tags look like `'RTL design (VHDL)'` or `'Vitis AI (1.4)'`.
# When grouping them by "family" I discard information about language or version.

# %%
# --- Initial raw count ---
implementationCounts = datapointsDf["Implementation"].value_counts()
print(implementationCounts)
print()

# -- Group by "family", i.e., discard version or language information in between parenthesis ---
def determine_impl_group(index: str) -> str:
    return index.split("(")[0].strip()
implementationGrouped = implementationCounts.groupby(determine_impl_group).sum()
print(implementationGrouped.sort_values(ascending=False))
# Out:
# Implementation
# RTL design (VHDL)       13
# RTL design (N/A)         7
# RTL design (Verilog)     7
# N/A                      7
# Vitis AI (N/A)           6
# HLS (Vitis)              6
# FINN                     4
# Vitis AI (DNNDK)         4
# HLS (N/A)                3
# RTL design (XSG)         3
# HLS (Vivado)             2
# HLS (VGT)                1
# Vitis AI (v2.5)          1
# Vitis AI (v1.4)          1
# HLS (MATLAB)             1
# Name: count, dtype: int64
#
# Implementation
# RTL design    30
# HLS           13
# Vitis AI      12
# N/A            7
# FINN           4
# Name: count, dtype: int64

# %% [markdown]
# ### FPGA boards
#
# A typical board tag looks like that: `'Zynq 7000 (Z7020) {Arty Z7}'`: `'<family> (<model>) {<evaluation board>}'`.
#
# The following cell groups the board by these 3 criteria.

# %%
# --- Initial raw count (of the full tags) ---
boardCounts = datapointsDf["Board"].value_counts()
# print(boardCounts)
# print()

# -- Group by "family", i.e., discard model in between parenthesis and evaluation board in between brackets ---
def determine_board_family_group(index: str) -> str:
    return index.split("(")[0].strip()
boardFamilyGrouped = boardCounts.groupby(determine_board_family_group).sum()
print(boardFamilyGrouped.sort_values(ascending=False))
print()

# -- Group by "board specific model", i.e., discard family and evaluation name in between brackets ---
def determine_board_model_group(index: str) -> str:
    return index.split("(")[1].split("{")[0].strip()[:-1]
boardModelGrouped = boardCounts.groupby(determine_board_model_group).sum()
print(boardModelGrouped.sort_values(ascending=False))
print()

# -- Group by "evaluation board/kit" (the name in between curly braces) ---
def determine_board_eval_group(index: str) -> str:
    boardKit: str = index.split("{")[1][:-1].strip()
    return boardKit if boardKit else "N/A   "
boardKitGrouped = boardCounts.groupby(determine_board_eval_group).sum()
print(boardKitGrouped.sort_values(ascending=False))
# Out:
# Board
# Zynq US+      24
# Zynq 7000     15
# Virtex-7      10
# Artix-7        6
# Kintex-7       3
# Virtex-6       3
# Kintex US      2
# Alveo          1
# Cyclone V      1
# Spartan-3A     1
# Name: count, dtype: int64
#
# Board
# XC7VX690T     10
# XC7Z020       10
# XCZU3EG        8
# XCZU7EV        7
# XCZU9EG        4
# XC7A35T        4
# XC6VLX240T     3
# XC7K325T       3
# XCZU15EG       3
# XC7Z045        2
# XCKU040        2
# XC7A200T       2
# XCZU19EG       1
# 5CSXC6         1
# XCK26          1
# XC7Z100        1
# U280           1
# XC7Z035        1
# XC3SD1800A     1
# Z7020          1
# Name: count, dtype: int64
#
# Board
# N/A                     17
# VC709                    7
# ZCU104                   6
# UltraZed-EG              4
# PYNQ-Z1                  3
# Arty-35T                 3
# ZCU102                   3
# OVC3                     3
# Alinx AXU15EG            3
# ZC706                    2
# Z-turn                   2
# AC701                    2
# KV260                    2
# KCU105                   2
# KC705                    2
# Ultra96                  1
# ZC702                    1
# Avnet Spartan-3A DSP     1
# Arty Z7                  1
# ZCU106                   1
# Name: count, dtype: int64

# %% [markdown]
# ### Model data
#
# Model information is already split in 3 Series: `'Model'`, `'Equivalent model'` and `'Backbone'`.
# I think grouping by `'Model'`, i.e., how the model is called in the article, makes no sense. However, even if `'Equivalent model'` is a subjective tag decided by myself, this conveys interressant information.
# Same for `'Backbone'`.

# %%
# ----- Initial dataframe -----
print_pretty_df(datapointsDf[["Model", "Equivalent model", "Backbone"]], max_rows=10)

# ----- Group by "Equivalent model" -----
equivalentModelCounts = datapointsDf["Equivalent model"].value_counts()
print(equivalentModelCounts)
print()

# ----- Group by "Backbone" -----
backbineCounts = (datapointsDf["Backbone"].value_counts().rename(lambda x: "N/A" if x == "" else x))
print(backbineCounts)
# Out:
# +---+---------------------+------------------+----------------+
# |   |        Model        | Equivalent model |    Backbone    |
# +---+---------------------+------------------+----------------+
# | 0 |         CNN         |       CNN        |                |
# | 1 | TriCloudNet + U-Net |       CNN        |   SqueezeNet   |
# | 2 |       YOLOv4        |      YOLOv4      |   Darknet53    |
# | 3 |   YOLOv4-tiny 3L    |      YOLOv4      | Darknet53-tiny |
# | 4 |      BRAM_DSP       |   Fuzzy ARTMAP   |                |
# | 5 |       LUT_MUL       |   Fuzzy ARTMAP   |                |
# | 6 |     LeNet-5 f32     |     LeNet-5      |    LeNet-5     |
# | 7 |     LeNet-5 i8      |     LeNet-5      |    LeNet-5     |
# | 8 |    Decision Tree    |        ML        |                |
# | 9 |       2D CNN        |       CNN        |                |
# +---+---------------------+------------------+----------------+
# Equivalent model
# CNN             28
# ML               7
# YOLOv2           7
# YOLOv4           4
# SSD              4
# LeNet-5          3
# GNN              3
# Fuzzy ARTMAP     2
# MLP              2
# YOLOv3           2
# RBM              1
# AlexNet          1
# WNS              1
# YOLOv4-tiny      1
# Name: count, dtype: int64
#
# Backbone
# N/A               34
# VGG16              6
# MobileNetv1        3
# LeNet-5            3
# Darknet19          3
# ResNet-50          2
# SqueezeNet         2
# ResNet-18          2
# AlexNet            1
# MobileNetv3        1
# MobileNeXt         1
# DarkNet53          1
# Darknet53-tiny     1
# Darknet53          1
# CSPDarknet53       1
# VGG11              1
# MobileNetv2        1
# ResNet-34          1
# GhostNet           1
# Name: count, dtype: int64

# %%
# ----- Find which model is based on MobileNetv2 -----
# If "Model", "Equivalent model" or "Backbone" contains "Mobile"
nbTotal = 0
for strLookFor in ["Mobile", "tiny", "Squeeze", "Ghost", "ENet", "ESP"]:
    nb = 0
    for index, row in datapointsDf.iterrows():
        if strLookFor in row["Model"] or strLookFor in row["Equivalent model"] or strLookFor in row["Backbone"]:
            print(row["Model"], row["Equivalent model"], row["Backbone"])
            nb += 1
    print(f"Number of experiments with {b}{strLookFor} = {nb}{e}")
    nbTotal += nb
print(f"Total = {r}{nbTotal}{e}/{len(datapointsDf)}{e}, or {r}{nbTotal / len(datapointsDf) * 100:.2f}%{e}")
# Out:
# YOLOv4-MobileNetv3 YOLOv4 MobileNetv3
# MobileNetv1Lite CNN MobileNetv1
# CBFF-SSD SSD MobileNetv1
# RFA-YOLO YOLOv4 MobileNeXt
# CNN2@0.7 YOLOv2 MobileNetv1
# CNN4@0.7 YOLOv2 MobileNetv2
# Number of experiments with Mobile = 6
# YOLOv4-tiny 3L YOLOv4 Darknet53-tiny
# Improved YOLOv4-tiny YOLOv4-tiny CSPDarknet53
# Number of experiments with tiny = 2
# TriCloudNet + U-Net CNN SqueezeNet
# CNN6@1.6 YOLOv2 SqueezeNet
# Number of experiments with Squeeze = 2
# Ghost-YOLOS YOLOv3 GhostNet
# Number of experiments with Ghost = 1
# ENet CNN
# Number of experiments with ENet = 1
# ESPNet CNN
# Number of experiments with ESP = 1
# Total = 13/66, or 19.70%

# %% [markdown]
# ## Trying to find tendencies
#
# ### Are Vitis AI implementations consuming more power?

# %%
# Let's plot the dataframe with only the following devices, and Deep Learning models
similar_devices = ["XCZU", "XCKU", "XQRKU", "XC7VX", "XCK26"]
DL_models = ["CNN", "YOLO", "AlexNet", "SSD", "Hybrid"]

# --- Filter the dataframe ---
similarBoardDf = datapointsDf[datapointsDf["Board"].str.contains("|".join(similar_devices), na=False)]
similarBoardAndModelsDf = similarBoardDf[
    similarBoardDf["Model"].str.contains("|".join(DL_models), na=False) |
    similarBoardDf["Equivalent model"].str.contains("|".join(DL_models), na=False) |
    similarBoardDf["Backbone"].str.contains("|".join(DL_models), na=False)
]
print(f"{len(similarBoardAndModelsDf)} experiments.")
# --- Print DF sorted by implementation ---
print_pretty_df(similarBoardAndModelsDf.sort_values(by="Implementation"))
# COmpute average "Power consumption" for all experiements using "Vitis AI", "HLS", and "RTL"
vitisAiDf = similarBoardAndModelsDf[similarBoardAndModelsDf["Implementation"].str.contains("Vitis AI", na=False)]
hlsDf = similarBoardAndModelsDf[similarBoardAndModelsDf["Implementation"].str.contains("HLS", na=False)]
rtlDf = similarBoardAndModelsDf[similarBoardAndModelsDf["Implementation"].str.contains("RTL", na=False)]
# write a function to compute the average power consumption of the given DF. Each cell should be pre-process: remove the "W" and convert to float
def compute_avg_power(df: pd.DataFrame) -> float:
    print_pretty_df(df)
    power = df["Power consumption"].str.replace("W", "")
    # Remove 'N/A' or empty values
    power = power[power != ""]
    print(power)
    return power.astype(float).mean()
print(f"Average power consumption for Vitis AI: {compute_avg_power(vitisAiDf)}W")
print(f"Average power consumption for HLS: {compute_avg_power(hlsDf)}W")
print(f"Average power consumption for RTL: {compute_avg_power(rtlDf)}W")
# Out:
# 32 experiments.
# +----+-------------------------------------------------------+----------------------+------------------+----------------+----------+---------------------------------------------------+----------------------+-----------------------------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------+-----------------------------------------+-------------------------------------------------------------+-------------------------------+------------+----------+----------+---------------------+
# |    |                   BBT Citation Key                    |        Model         | Equivalent model |    Backbone    | Modality |                      Dataset                      |         Task         |               Application               |                Board                |    Implementation    | Publication year |  Latency  |    FPS     | Task score | Footprint |  Throughput  | Power consumption | Frequency  | Complexity  |               Design                |  Memory  |                Precision                |                        Optimizations                        |           FPGA Util           | DPU Config | DPU Core | DPU Util |  DPU Optimizations  |
# +----+-------------------------------------------------------+----------------------+------------------+----------------+----------+---------------------------------------------------+----------------------+-----------------------------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------+-----------------------------------------+-------------------------------------------------------------+-------------------------------+------------+----------+----------+---------------------+
# | 53 |          gargAircraftDetectionSatellite2024           |   ResNet-18+YOLOv2   |      YOLOv2      |   ResNet-18    |   RGB    |             Airbus {Object Detection}             |   Object detection   |           Aircraft detection            |     Zynq US+ (XCZU9EG) {ZCU102}     |     HLS (MATLAB)     |       2024       |           |   46 FPS   |   91% AP   |           |              |                   |  250 MHz   |             |           Model Specific            | Off-chip |                Fixed (8)                |                           ['N/A']                           |              N/A              |            |          |          |         []          |
# | 29 |           wuDesignImplementationRemote2021            |   Improved YOLOv3    |      YOLOv3      |   DarkNet53    |   RGB    | Google Earth Studio RGB (sim.) {Object Detection} |   Object detection   |           Aircraft detection            |        Zynq US+ (XCZU9EG) {}        |      HLS (N/A)       |       2021       |   7 ms    |            |   92% OA   |  8.50 MB  |              |                   |            |             |           Various Kernels           | Off-chip |                Fixed (8)                |                      ['Multiple PEs']                       |              N/A              |            |          |          |         []          |
# | 44 |           yangAlgorithmHardwareCodesign2022           |       CNN4@0.7       |      YOLOv2      |  MobileNetv2   |   SAR    |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |    Virtex-7 (XC7VX690T) {VC709}     |     HLS (Vitis)      |       2022       |  0.7 ms   |  636 FPS   |  93.3% AP  |  0.11 MB  |  366 GOP/s   |      6.60 W       |  250 MHz   |  0.56G OP   | Model Specific (All layers on FPGA) | On-chip  |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |  Average (69% DSP,21% BRAM)   |            |          |          |         []          |
# | 43 |           yangAlgorithmHardwareCodesign2022           |       CNN2@0.7       |      YOLOv2      |  MobileNetv1   |   SAR    |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |    Virtex-7 (XC7VX690T) {VC709}     |     HLS (Vitis)      |       2022       |  0.7 ms   |  652 FPS   |   94% AP   |  0.09 MB  |  298 GOP/s   |      5.80 W       |  250 MHz   |  0.45G OP   | Model Specific (All layers on FPGA) | On-chip  |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |  Average (64% DSP,21% BRAM)   |            |          |          |         []          |
# | 45 |           yangAlgorithmHardwareCodesign2022           |       CNN6@1.6       |      YOLOv2      |   SqueezeNet   |   SAR    |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |    Virtex-7 (XC7VX690T) {VC709}     |     HLS (Vitis)      |       2022       |  1.6 ms   |  384 FPS   |  92.8% AP  |  0.09 MB  |  235 GOP/s   |      5.10 W       |  250 MHz   |   0.6G OP   | Model Specific (All layers on FPGA) | On-chip  |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |  Average (76% DSP,18% BRAM)   |            |          |          |         []          |
# | 22 |         nerisFPGABasedImplementationCNN2022a          |     AlexNetLite      |     AlexNet      |    AlexNet     |   RGB    |              MASATI {Classification}              |    Classification    |           Ship identification           |    Kintex US (XCKU040) {KCU105}     |     HLS (Vitis)      |       2022       |           |            |   89% F1   |           |              |                   |  200 MHz   |  5.71G OP   |                 N/A                 |   N/A    |               Fixed (16)                |                           ['N/A']                           |    Low (31% DSP,39% BRAM)     |            |          |          |         []          |
# | 23 |         nerisFPGABasedImplementationCNN2022a          |   MobileNetv1Lite    |       CNN        |  MobileNetv1   |   RGB    |              MASATI {Classification}              |    Classification    |           Ship identification           |    Kintex US (XCKU040) {KCU105}     |     HLS (Vitis)      |       2022       |           |            |   94% F1   |           |              |                   |  200 MHz   |  0.05G OP   |                 N/A                 |   N/A    |               Fixed (16)                |                           ['N/A']                           |    Low (31% DSP,39% BRAM)     |            |          |          |         []          |
# | 49 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |      SSD 0.25x       |       SSD        |     VGG16      |   RGB    |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |      Zynq US+ (XCZU3EG) {OVC3}      |         N/A          |       2021       |           | 34.18 FPS  | 76.2% mAP  |           |  138 GOP/s   |      2.40 W       |  200 MHz   |  4.04G OP   |           Various Kernels           | Off-chip |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |      (73% DSP, 47% BRAM)      |            |          |          |         []          |
# | 50 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |       SSD 0.5x       |       SSD        |     VGG16      |   RGB    |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |      Zynq US+ (XCZU3EG) {OVC3}      |         N/A          |       2021       |           |  9.6 FPS   | 83.9% mAP  |           |  150 GOP/s   |      2.60 W       |  200 MHz   |  15.65G OP  |           Various Kernels           | Off-chip |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |   High (73% DSP, 55% BRAM)    |            |          |          |         []          |
# | 51 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |       SSD 1.0x       |       SSD        |     VGG16      |   RGB    |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |      Zynq US+ (XCZU3EG) {OVC3}      |         N/A          |       2021       |           |  2.56 FPS  | 88.4% mAP  |           |  158 GOP/s   |      2.00 W       |  200 MHz   |  61.60G OP  |           Various Kernels           | Off-chip |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |                               |            |          |          |         []          |
# | 39 |         zhangExtremelyPipelinedFPGAbased2023a         |         A2NN         |       CNN        |     VGG11      |   RGB    |        UC-Merced Land Use {Classification}        |    Classification    |           Landcover/Land use            |       Virtex-7 (XC7VX690T) {}       |   RTL design (N/A)   |       2023       |  4.92 ms  | 203.25 FPS | 94.76% OA  |           |  3047 GOP/s  |      8.27 W       |  200 MHz   |  14.99G OP  |           Model Specific            | On-chip  |      Mixed (Fixed 4 and Float 32)       |                      ['Multiple PEs']                       |    Low (9% DSP, 86% BRAM)     |            |          |          |         []          |
# | 16 |              liNovelCNNBasedAP2DNet2020               |       AP2D-Net       |       CNN        |                |   RGB    |        UAV RGB (cust.) {Object Detection}         |   Object detection   |                 Diverse                 |    Zynq US+ (XCZU3EG) {Ultra96}     |   RTL design (N/A)   |       2020       |  32.8 ms  | 30.53 FPS  | 55.0% mIoU |           | 130.20 GOP/s |      5.59 W       |  300 MHz   |             |           Various Kernels           | Off-chip | Mixed (Fixed (1 to 24) weights (3) act) |                        ['SIMD MVU']                         |   High (80% DSP, 75% BRAM)    |            |          |          |         []          |
# | 11 |                heConfigurable2D3D2023a                |       HybridSN       |       CNN        |                |   HSI    |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 7.71 ms*  |            |  100% OA   | 20.50 MB  | 13.18 GOP/s  |      8.40 W       |  100 MHz   | 101.642M OP |           Various Kernels           | Off-chip |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |  Average (37% DSP, 80% BRAM)  |            |          |          |         []          |
# | 10 |                heConfigurable2D3D2023a                |        3D CNN        |       CNN        |                |   HSI    |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 1.11 ms*  |            | 94.09% OA  |  0.12 MB  |  3.81 GOP/s  |      8.40 W       |  100 MHz   |  4.231M OP  |           Various Kernels           | Off-chip |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |   Low (27.9% DSP, 76% BRAM)   |            |          |          |         []          |
# | 9  |                heConfigurable2D3D2023a                |        2D CNN        |       CNN        |                |   HSI    |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 0.097 ms* |            | 98.24% OA  |  1.20 MB  |  7.07 GOP/s  |      8.40 W       |  100 MHz   |  0.684M OP  |           Various Kernels           | Off-chip |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |   Low (22.5% DSP, 71% BRAM)   |            |          |          |         []          |
# | 38 |       rapuanoFPGAbasedHardwareAccelerator2021a        |      CloudScout      |       CNN        |                |   HSI    |        Sentinel-2 (cust.) {Classification}        |    Classification    |             Cloud coverage              |     Zynq US+ (XCZU7EV) {ZCU106}     |  RTL design (VHDL)   |       2021       | 141.7 ms  |            |  92.0% OA  | 13.30 MB  |              |      3.40 W       | 115.4 MHz  |             |           Model Specific            | Off-chip |              Mixed (Fixed)              |            ['Advanced Dataflow', 'Multiple PEs']            | High (67% DSP, 46% BRAM+URAM) |            |          |          |         []          |
# | 41 |       zhangEfficientFPGABasedImplementation2020       |        Q-IORN        |       CNN        |     VGG16      |   RGB    |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |    Virtex-7 (XC7VX690T) {VC709}     |  RTL design (VHDL)   |       2020       | 147.62 ms |  6.77 FPS  | 88.31% OA  | 121.51 MB | 209.60 GOP/s |      6.32 W       |  200 MHz   |             |           Model Specific            | Off-chip |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |    Low (21% DSP, 27% BRAM)    |            |          |          |         []          |
# | 48 |         niAlgorithmHardwareCoOptimization2023         |        VGG16         |       CNN        |     VGG16      |   RGB    |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       |  89.1 ms  |            | 91.90% OA  | 14.70 MB  |  344 GOP/s   |      14.97 W      |  200 MHz   |  30.69G OP  |           Various Kernels           | Off-chip |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |    Low (23% DSP, 54% BRAM)    |            |          |          |         []          |
# | 47 |         niAlgorithmHardwareCoOptimization2023         |      ResNet-34       |       CNN        |   ResNet-34    |   RGB    |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       |  40.2 ms  |            | 92.81% OA  | 21.29 MB  |  182 GOP/s   |      14.97 W      |  200 MHz   |  7.33G OP   |           Various Kernels           | Off-chip |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |    Low (23% DSP, 54% BRAM)    |            |          |          |         []          |
# | 46 |         niAlgorithmHardwareCoOptimization2023         |   Improved YOLOv2    |      YOLOv2      |   Darknet19    |   RGB    |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       | 981.4 ms  |            | 67.30% mAP | 49.40 MB  |  387 GOP/s   |      14.97 W      |  200 MHz   | 379.55G OP  |           Various Kernels           | Off-chip |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |    Low (23% DSP, 54% BRAM)    |            |          |          |         []          |
# | 61 |      sabogalMethodologyEvaluatingAnalyzing2021a       |        ESPNet        |       CNN        |                |   RGB    |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |  Zynq US+ (XCZU3EG) {UltraZed-EG}   |   Vitis AI (DNNDK)   |       2021       |           |  11.7 FPS  | 55.5% mIoU |  0.33 MB  |              |      3.08 W       |  300 MHz   |  3.71G OP   |                                     |          |                Fixed (8)                |                             []                              |   High (70% DSP, 75% BRAM)    |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 60 |      sabogalMethodologyEvaluatingAnalyzing2021a       |         ENet         |       CNN        |                |   RGB    |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |  Zynq US+ (XCZU3EG) {UltraZed-EG}   |   Vitis AI (DNNDK)   |       2021       |           |  25.2 FPS  | 63.3% mIoU |  0.36 MB  |              |      3.36 W       |  300 MHz   |  4.06G OP   |                                     |          |                Fixed (8)                |                             []                              |   High (70% DSP, 75% BRAM)    |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 63 |      sabogalMethodologyEvaluatingAnalyzing2021a       |        U-Net         |       CNN        |                |   RGB    |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |  Zynq US+ (XCZU3EG) {UltraZed-EG}   |   Vitis AI (DNNDK)   |       2021       |           |  2.7 FPS   | 61.4% mIoU |  7.40 MB  |              |      3.38 W       |  300 MHz   |  96.68G OP  |                                     |          |                Fixed (8)                |                             []                              |   High (70% DSP, 75% BRAM)    |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 62 |      sabogalMethodologyEvaluatingAnalyzing2021a       |         FPN          |       CNN        |                |   RGB    |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |  Zynq US+ (XCZU3EG) {UltraZed-EG}   |   Vitis AI (DNNDK)   |       2021       |           |  14.1 FPS  | 65.3% mIoU |  5.84 MB  |              |      4.03 W       |  300 MHz   |  17.30G OP  |                                     |          |                Fixed (8)                |                             []                              |   High (70% DSP, 75% BRAM)    |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 31 |       upadhyayDesignImplementationCNNbased2024        |        SICNet        |       CNN        |                |   RGB    |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |     Zynq US+ (XCZU9EG) {ZCU102}     |    Vitis AI (N/A)    |       2024       |  1.8 ms   | 530.66 FPS | 85.76% OA  |           |              |                   |            |             |                                     |          |                Fixed (8)                |                             []                              |                               |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 30 |       upadhyayDesignImplementationCNNbased2024        |      ResNet-50       |       CNN        |   ResNet-50    |   RGB    |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |     Zynq US+ (XCZU9EG) {ZCU102}     |    Vitis AI (N/A)    |       2024       |  10.7 ms  | 93.02 FPS  |            |           |              |                   |            |             |                                     |          |                Fixed (8)                |                             []                              |                               |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 27 |               liEdgeRealtimeObject2023a               |       RFA-YOLO       |      YOLOv4      |   MobileNeXt   |   RGB    |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |     Zynq US+ (XCZU7EV) {ZCU104}     |    Vitis AI (N/A)    |       2023       |           | 27.97 FPS  | 64.85% mAP | 24.75 MB  |              |      15.82 W      |  200 MHz   |             |                                     |          |                Fixed (8)                |                             []                              |              N/A              |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 3  |         nguyenFPGASoCImplementationYOLOv42024         |    YOLOv4-tiny 3L    |      YOLOv4      | Darknet53-tiny |   RGB    |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |     Zynq US+ (XCZU7EV) {ZCU104}     |    Vitis AI (N/A)    |       2024       | 19.18 ms  |  125 FPS   | 72.24% mAP | 24.10 MB  |              |      26.40 W      |  100 MHz   |  15.32G OP  |                                     |          |                Fixed (8)                |                             []                              |              N/A              |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 42 |              huangEdgeTrustworthyAI2024               |        ETAUS         |       CNN        |   ResNet-50    |   HSI    |         UAV RGB (cust.) {Classification}          |    Classification    |         Air Quality Monitoring          |     Zynq US+ (XCZU19EG) {KV260}     |    Vitis AI (N/A)    |       2024       | 107.8 ms  |  9.3 FPS   | 86.38% F1  |           | 329.90 GOP/s |      1.65 W       | 106.25 MHz |  329.9G OP  |                                     |          |                Fixed (8)                |                             []                              |              N/A              |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 2  |         nguyenFPGASoCImplementationYOLOv42024         |        YOLOv4        |      YOLOv4      |   Darknet53    |   RGB    |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |     Zynq US+ (XCZU7EV) {ZCU104}     |    Vitis AI (N/A)    |       2024       | 107.94 ms |  17.9 FPS  | 83.7% mAP  |  245 MB   |              |      30.1 W       |  100 MHz   |  105.9G OP  |                                     |          |                Fixed (8)                |                             []                              |              N/A              |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 37 |             yuImprovedLightweightDeep2024             | Improved YOLOv4-tiny |   YOLOv4-tiny    |  CSPDarknet53  |   RGB    |    FastenerDataset (cust.) {Object Detection}     |   Object detection   | Railway track fastener defect detection |     Zynq US+ (XCZU7EV) {ZCU104}     |   Vitis AI (v1.4)    |       2024       |           | 295.9 FPS  | 95.1% mAP  |           |              |      20.00 W      |  300 MHz   |             |                                     |          |                Fixed (8)                |                             []                              |              N/A              |   B4096    |    2     |   N/A    |    ['UltraRAM']     |
# | 20 |        zhaoHardwareAccelerationSatellite2023a         |  YOLOv4-MobileNetv3  |      YOLOv4      |  MobileNetv3   |   RGB    |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |      Zynq US+ (XCK26) {KV260}       |   Vitis AI (v2.5)    |       2023       |           | 48.14 FPS  | 82.61% mAP |  5.69 MB  |              |      7.20 W       |  200 MHz   |             |                                     |          |                Fixed (8)                |                             []                              |  Average (59% DSP, N/A BRAM)  |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# +----+-------------------------------------------------------+----------------------+------------------+----------------+----------+---------------------------------------------------+----------------------+-----------------------------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------+-----------------------------------------+-------------------------------------------------------------+-------------------------------+------------+----------+----------+---------------------+
# +----+--------------------------------------------+----------------------+------------------+----------------+----------+--------------------------------------------+------------------+-----------------------------------------+----------------------------------+------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+---------------------+
# |    |              BBT Citation Key              |        Model         | Equivalent model |    Backbone    | Modality |                  Dataset                   |       Task       |               Application               |              Board               |  Implementation  | Publication year |  Latency  |    FPS     | Task score | Footprint |  Throughput  | Power consumption | Frequency  | Complexity | Design | Memory | Precision | Optimizations |          FPGA Util          | DPU Config | DPU Core | DPU Util |  DPU Optimizations  |
# +----+--------------------------------------------+----------------------+------------------+----------------+----------+--------------------------------------------+------------------+-----------------------------------------+----------------------------------+------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+---------------------+
# | 2  |   nguyenFPGASoCImplementationYOLOv42024    |        YOLOv4        |      YOLOv4      |   Darknet53    |   RGB    |     UAV RGB (cust.) {Object Detection}     | Object detection |         Flying-object detection         |   Zynq US+ (XCZU7EV) {ZCU104}    |  Vitis AI (N/A)  |       2024       | 107.94 ms |  17.9 FPS  | 83.7% mAP  |  245 MB   |              |      30.1 W       |  100 MHz   | 105.9G OP  |        |        | Fixed (8) |      []       |             N/A             |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 3  |   nguyenFPGASoCImplementationYOLOv42024    |    YOLOv4-tiny 3L    |      YOLOv4      | Darknet53-tiny |   RGB    |     UAV RGB (cust.) {Object Detection}     | Object detection |         Flying-object detection         |   Zynq US+ (XCZU7EV) {ZCU104}    |  Vitis AI (N/A)  |       2024       | 19.18 ms  |  125 FPS   | 72.24% mAP | 24.10 MB  |              |      26.40 W      |  100 MHz   | 15.32G OP  |        |        | Fixed (8) |      []       |             N/A             |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 20 |   zhaoHardwareAccelerationSatellite2023a   |  YOLOv4-MobileNetv3  |      YOLOv4      |  MobileNetv3   |   RGB    |          DIOR {Object Detection}           | Object detection |                 Diverse                 |     Zynq US+ (XCK26) {KV260}     | Vitis AI (v2.5)  |       2023       |           | 48.14 FPS  | 82.61% mAP |  5.69 MB  |              |      7.20 W       |  200 MHz   |            |        |        | Fixed (8) |      []       | Average (59% DSP, N/A BRAM) |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 27 |         liEdgeRealtimeObject2023a          |       RFA-YOLO       |      YOLOv4      |   MobileNeXt   |   RGB    |          DIOR {Object Detection}           | Object detection |                 Diverse                 |   Zynq US+ (XCZU7EV) {ZCU104}    |  Vitis AI (N/A)  |       2023       |           | 27.97 FPS  | 64.85% mAP | 24.75 MB  |              |      15.82 W      |  200 MHz   |            |        |        | Fixed (8) |      []       |             N/A             |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 30 |  upadhyayDesignImplementationCNNbased2024  |      ResNet-50       |       CNN        |   ResNet-50    |   RGB    |        RGB (cust.) {Classification}        |  Classification  |             Cloud coverage              |   Zynq US+ (XCZU9EG) {ZCU102}    |  Vitis AI (N/A)  |       2024       |  10.7 ms  | 93.02 FPS  |            |           |              |                   |            |            |        |        | Fixed (8) |      []       |                             |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 31 |  upadhyayDesignImplementationCNNbased2024  |        SICNet        |       CNN        |                |   RGB    |        RGB (cust.) {Classification}        |  Classification  |             Cloud coverage              |   Zynq US+ (XCZU9EG) {ZCU102}    |  Vitis AI (N/A)  |       2024       |  1.8 ms   | 530.66 FPS | 85.76% OA  |           |              |                   |            |            |        |        | Fixed (8) |      []       |                             |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 37 |       yuImprovedLightweightDeep2024        | Improved YOLOv4-tiny |   YOLOv4-tiny    |  CSPDarknet53  |   RGB    | FastenerDataset (cust.) {Object Detection} | Object detection | Railway track fastener defect detection |   Zynq US+ (XCZU7EV) {ZCU104}    | Vitis AI (v1.4)  |       2024       |           | 295.9 FPS  | 95.1% mAP  |           |              |      20.00 W      |  300 MHz   |            |        |        | Fixed (8) |      []       |             N/A             |   B4096    |    2     |   N/A    |    ['UltraRAM']     |
# | 42 |         huangEdgeTrustworthyAI2024         |        ETAUS         |       CNN        |   ResNet-50    |   HSI    |      UAV RGB (cust.) {Classification}      |  Classification  |         Air Quality Monitoring          |   Zynq US+ (XCZU19EG) {KV260}    |  Vitis AI (N/A)  |       2024       | 107.8 ms  |  9.3 FPS   | 86.38% F1  |           | 329.90 GOP/s |      1.65 W       | 106.25 MHz | 329.9G OP  |        |        | Fixed (8) |      []       |             N/A             |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 60 | sabogalMethodologyEvaluatingAnalyzing2021a |         ENet         |       CNN        |                |   RGB    |           Potsdam {Segmentation}           |   Segmentation   |               Urban areas               | Zynq US+ (XCZU3EG) {UltraZed-EG} | Vitis AI (DNNDK) |       2021       |           |  25.2 FPS  | 63.3% mIoU |  0.36 MB  |              |      3.36 W       |  300 MHz   |  4.06G OP  |        |        | Fixed (8) |      []       |  High (70% DSP, 75% BRAM)   |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 61 | sabogalMethodologyEvaluatingAnalyzing2021a |        ESPNet        |       CNN        |                |   RGB    |           Potsdam {Segmentation}           |   Segmentation   |               Urban areas               | Zynq US+ (XCZU3EG) {UltraZed-EG} | Vitis AI (DNNDK) |       2021       |           |  11.7 FPS  | 55.5% mIoU |  0.33 MB  |              |      3.08 W       |  300 MHz   |  3.71G OP  |        |        | Fixed (8) |      []       |  High (70% DSP, 75% BRAM)   |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 62 | sabogalMethodologyEvaluatingAnalyzing2021a |         FPN          |       CNN        |                |   RGB    |           Potsdam {Segmentation}           |   Segmentation   |               Urban areas               | Zynq US+ (XCZU3EG) {UltraZed-EG} | Vitis AI (DNNDK) |       2021       |           |  14.1 FPS  | 65.3% mIoU |  5.84 MB  |              |      4.03 W       |  300 MHz   | 17.30G OP  |        |        | Fixed (8) |      []       |  High (70% DSP, 75% BRAM)   |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 63 | sabogalMethodologyEvaluatingAnalyzing2021a |        U-Net         |       CNN        |                |   RGB    |           Potsdam {Segmentation}           |   Segmentation   |               Urban areas               | Zynq US+ (XCZU3EG) {UltraZed-EG} | Vitis AI (DNNDK) |       2021       |           |  2.7 FPS   | 61.4% mIoU |  7.40 MB  |              |      3.38 W       |  300 MHz   | 96.68G OP  |        |        | Fixed (8) |      []       |  High (70% DSP, 75% BRAM)   |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# +----+--------------------------------------------+----------------------+------------------+----------------+----------+--------------------------------------------+------------------+-----------------------------------------+----------------------------------+------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+------------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+---------------------+
# 2      30.1
# 3     26.40
# 20     7.20
# 27    15.82
# 37    20.00
# 42     1.65
# 60     3.36
# 61     3.08
# 62     4.03
# 63     3.38
# Name: Power consumption, dtype: object
# Average power consumption for Vitis AI: 11.501999999999999W
# +----+--------------------------------------+------------------+------------------+-------------+----------+---------------------------------------------------+------------------+---------------------+------------------------------+----------------+------------------+---------+---------+------------+-----------+------------+-------------------+-----------+------------+-------------------------------------+----------+---------------------+-------------------------------------------------------------+----------------------------+------------+----------+----------+-------------------+
# |    |           BBT Citation Key           |      Model       | Equivalent model |  Backbone   | Modality |                      Dataset                      |       Task       |     Application     |            Board             | Implementation | Publication year | Latency |   FPS   | Task score | Footprint | Throughput | Power consumption | Frequency | Complexity |               Design                |  Memory  |      Precision      |                        Optimizations                        |         FPGA Util          | DPU Config | DPU Core | DPU Util | DPU Optimizations |
# +----+--------------------------------------+------------------+------------------+-------------+----------+---------------------------------------------------+------------------+---------------------+------------------------------+----------------+------------------+---------+---------+------------+-----------+------------+-------------------+-----------+------------+-------------------------------------+----------+---------------------+-------------------------------------------------------------+----------------------------+------------+----------+----------+-------------------+
# | 22 | nerisFPGABasedImplementationCNN2022a |   AlexNetLite    |     AlexNet      |   AlexNet   |   RGB    |              MASATI {Classification}              |  Classification  | Ship identification | Kintex US (XCKU040) {KCU105} |  HLS (Vitis)   |       2022       |         |         |   89% F1   |           |            |                   |  200 MHz  |  5.71G OP  |                 N/A                 |   N/A    |     Fixed (16)      |                           ['N/A']                           |   Low (31% DSP,39% BRAM)   |            |          |          |        []         |
# | 23 | nerisFPGABasedImplementationCNN2022a | MobileNetv1Lite  |       CNN        | MobileNetv1 |   RGB    |              MASATI {Classification}              |  Classification  | Ship identification | Kintex US (XCKU040) {KCU105} |  HLS (Vitis)   |       2022       |         |         |   94% F1   |           |            |                   |  200 MHz  |  0.05G OP  |                 N/A                 |   N/A    |     Fixed (16)      |                           ['N/A']                           |   Low (31% DSP,39% BRAM)   |            |          |          |        []         |
# | 29 |   wuDesignImplementationRemote2021   | Improved YOLOv3  |      YOLOv3      |  DarkNet53  |   RGB    | Google Earth Studio RGB (sim.) {Object Detection} | Object detection | Aircraft detection  |    Zynq US+ (XCZU9EG) {}     |   HLS (N/A)    |       2021       |  7 ms   |         |   92% OA   |  8.50 MB  |            |                   |           |            |           Various Kernels           | Off-chip |      Fixed (8)      |                      ['Multiple PEs']                       |            N/A             |            |          |          |        []         |
# | 43 |  yangAlgorithmHardwareCodesign2022   |     CNN2@0.7     |      YOLOv2      | MobileNetv1 |   SAR    |              SSDD {Object Detection}              | Object detection |   Ship detection    | Virtex-7 (XC7VX690T) {VC709} |  HLS (Vitis)   |       2022       | 0.7 ms  | 652 FPS |   94% AP   |  0.09 MB  | 298 GOP/s  |      5.80 W       |  250 MHz  |  0.45G OP  | Model Specific (All layers on FPGA) | On-chip  | Mixed width (MPQAT) | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] | Average (64% DSP,21% BRAM) |            |          |          |        []         |
# | 44 |  yangAlgorithmHardwareCodesign2022   |     CNN4@0.7     |      YOLOv2      | MobileNetv2 |   SAR    |              SSDD {Object Detection}              | Object detection |   Ship detection    | Virtex-7 (XC7VX690T) {VC709} |  HLS (Vitis)   |       2022       | 0.7 ms  | 636 FPS |  93.3% AP  |  0.11 MB  | 366 GOP/s  |      6.60 W       |  250 MHz  |  0.56G OP  | Model Specific (All layers on FPGA) | On-chip  | Mixed width (MPQAT) | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] | Average (69% DSP,21% BRAM) |            |          |          |        []         |
# | 45 |  yangAlgorithmHardwareCodesign2022   |     CNN6@1.6     |      YOLOv2      | SqueezeNet  |   SAR    |              SSDD {Object Detection}              | Object detection |   Ship detection    | Virtex-7 (XC7VX690T) {VC709} |  HLS (Vitis)   |       2022       | 1.6 ms  | 384 FPS |  92.8% AP  |  0.09 MB  | 235 GOP/s  |      5.10 W       |  250 MHz  |  0.6G OP   | Model Specific (All layers on FPGA) | On-chip  | Mixed width (MPQAT) | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] | Average (76% DSP,18% BRAM) |            |          |          |        []         |
# | 53 |  gargAircraftDetectionSatellite2024  | ResNet-18+YOLOv2 |      YOLOv2      |  ResNet-18  |   RGB    |             Airbus {Object Detection}             | Object detection | Aircraft detection  | Zynq US+ (XCZU9EG) {ZCU102}  |  HLS (MATLAB)  |       2024       |         | 46 FPS  |   91% AP   |           |            |                   |  250 MHz  |            |           Model Specific            | Off-chip |      Fixed (8)      |                           ['N/A']                           |            N/A             |            |          |          |        []         |
# +----+--------------------------------------+------------------+------------------+-------------+----------+---------------------------------------------------+------------------+---------------------+------------------------------+----------------+------------------+---------+---------+------------+-----------+------------+-------------------+-----------+------------+-------------------------------------+----------+---------------------+-------------------------------------------------------------+----------------------------+------------+----------+----------+-------------------+
# 43    5.80
# 44    6.60
# 45    5.10
# Name: Power consumption, dtype: object
# Average power consumption for HLS: 5.833333333333333W
# +----+-------------------------------------------+-----------------+------------------+-----------+----------+--------------------------------------------+----------------------+--------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+-----------+-------------+-----------------+----------+-----------------------------------------+---------------------------------------+-------------------------------+------------+----------+----------+-------------------+
# |    |             BBT Citation Key              |      Model      | Equivalent model | Backbone  | Modality |                  Dataset                   |         Task         |    Application     |                Board                |    Implementation    | Publication year |  Latency  |    FPS     | Task score | Footprint |  Throughput  | Power consumption | Frequency | Complexity  |     Design      |  Memory  |                Precision                |             Optimizations             |           FPGA Util           | DPU Config | DPU Core | DPU Util | DPU Optimizations |
# +----+-------------------------------------------+-----------------+------------------+-----------+----------+--------------------------------------------+----------------------+--------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+-----------+-------------+-----------------+----------+-----------------------------------------+---------------------------------------+-------------------------------+------------+----------+----------+-------------------+
# | 9  |          heConfigurable2D3D2023a          |     2D CNN      |       CNN        |           |   HSI    | University of Pavia {Pixel classification} | Pixel classification | Landcover/Land use | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 0.097 ms* |            | 98.24% OA  |  1.20 MB  |  7.07 GOP/s  |      8.40 W       |  100 MHz  |  0.684M OP  | Various Kernels | Off-chip |                Fixed (8)                | ['Advanced Dataflow', 'Multiple PEs'] |   Low (22.5% DSP, 71% BRAM)   |            |          |          |        []         |
# | 10 |          heConfigurable2D3D2023a          |     3D CNN      |       CNN        |           |   HSI    | University of Pavia {Pixel classification} | Pixel classification | Landcover/Land use | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 1.11 ms*  |            | 94.09% OA  |  0.12 MB  |  3.81 GOP/s  |      8.40 W       |  100 MHz  |  4.231M OP  | Various Kernels | Off-chip |                Fixed (8)                | ['Advanced Dataflow', 'Multiple PEs'] |   Low (27.9% DSP, 76% BRAM)   |            |          |          |        []         |
# | 11 |          heConfigurable2D3D2023a          |    HybridSN     |       CNN        |           |   HSI    | University of Pavia {Pixel classification} | Pixel classification | Landcover/Land use | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 7.71 ms*  |            |  100% OA   | 20.50 MB  | 13.18 GOP/s  |      8.40 W       |  100 MHz  | 101.642M OP | Various Kernels | Off-chip |                Fixed (8)                | ['Advanced Dataflow', 'Multiple PEs'] |  Average (37% DSP, 80% BRAM)  |            |          |          |        []         |
# | 16 |        liNovelCNNBasedAP2DNet2020         |    AP2D-Net     |       CNN        |           |   RGB    |     UAV RGB (cust.) {Object Detection}     |   Object detection   |      Diverse       |    Zynq US+ (XCZU3EG) {Ultra96}     |   RTL design (N/A)   |       2020       |  32.8 ms  | 30.53 FPS  | 55.0% mIoU |           | 130.20 GOP/s |      5.59 W       |  300 MHz  |             | Various Kernels | Off-chip | Mixed (Fixed (1 to 24) weights (3) act) |             ['SIMD MVU']              |   High (80% DSP, 75% BRAM)    |            |          |          |        []         |
# | 38 | rapuanoFPGAbasedHardwareAccelerator2021a  |   CloudScout    |       CNN        |           |   HSI    |    Sentinel-2 (cust.) {Classification}     |    Classification    |   Cloud coverage   |     Zynq US+ (XCZU7EV) {ZCU106}     |  RTL design (VHDL)   |       2021       | 141.7 ms  |            |  92.0% OA  | 13.30 MB  |              |      3.40 W       | 115.4 MHz |             | Model Specific  | Off-chip |              Mixed (Fixed)              | ['Advanced Dataflow', 'Multiple PEs'] | High (67% DSP, 46% BRAM+URAM) |            |          |          |        []         |
# | 39 |   zhangExtremelyPipelinedFPGAbased2023a   |      A2NN       |       CNN        |   VGG11   |   RGB    |    UC-Merced Land Use {Classification}     |    Classification    | Landcover/Land use |       Virtex-7 (XC7VX690T) {}       |   RTL design (N/A)   |       2023       |  4.92 ms  | 203.25 FPS | 94.76% OA  |           |  3047 GOP/s  |      8.27 W       |  200 MHz  |  14.99G OP  | Model Specific  | On-chip  |      Mixed (Fixed 4 and Float 32)       |           ['Multiple PEs']            |    Low (9% DSP, 86% BRAM)     |            |          |          |        []         |
# | 41 | zhangEfficientFPGABasedImplementation2020 |     Q-IORN      |       CNN        |   VGG16   |   RGB    |       NWPU-RESISC45 {Classification}       |    Classification    | Landcover/Land use |    Virtex-7 (XC7VX690T) {VC709}     |  RTL design (VHDL)   |       2020       | 147.62 ms |  6.77 FPS  | 88.31% OA  | 121.51 MB | 209.60 GOP/s |      6.32 W       |  200 MHz  |             | Model Specific  | Off-chip |                Fixed (8)                | ['Advanced Dataflow', 'Multiple PEs'] |    Low (21% DSP, 27% BRAM)    |            |          |          |        []         |
# | 46 |   niAlgorithmHardwareCoOptimization2023   | Improved YOLOv2 |      YOLOv2      | Darknet19 |   RGB    |        DOTAv1.0 {Object Detection}         |   Object detection   |      Diverse       |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       | 981.4 ms  |            | 67.30% mAP | 49.40 MB  |  387 GOP/s   |      14.97 W      |  200 MHz  | 379.55G OP  | Various Kernels | Off-chip |      Mixed width (Fixed 32 and 8)       |           ['Multiple PEs']            |    Low (23% DSP, 54% BRAM)    |            |          |          |        []         |
# | 47 |   niAlgorithmHardwareCoOptimization2023   |    ResNet-34    |       CNN        | ResNet-34 |   RGB    |       NWPU-RESISC45 {Classification}       |    Classification    | Landcover/Land use |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       |  40.2 ms  |            | 92.81% OA  | 21.29 MB  |  182 GOP/s   |      14.97 W      |  200 MHz  |  7.33G OP   | Various Kernels | Off-chip |      Mixed width (Fixed 32 and 8)       |           ['Multiple PEs']            |    Low (23% DSP, 54% BRAM)    |            |          |          |        []         |
# | 48 |   niAlgorithmHardwareCoOptimization2023   |      VGG16      |       CNN        |   VGG16   |   RGB    |       NWPU-RESISC45 {Classification}       |    Classification    | Landcover/Land use |    Virtex-7 (XC7VX690T) {VC709}     | RTL design (Verilog) |       2023       |  89.1 ms  |            | 91.90% OA  | 14.70 MB  |  344 GOP/s   |      14.97 W      |  200 MHz  |  30.69G OP  | Various Kernels | Off-chip |      Mixed width (Fixed 32 and 8)       |           ['Multiple PEs']            |    Low (23% DSP, 54% BRAM)    |            |          |          |        []         |
# +----+-------------------------------------------+-----------------+------------------+-----------+----------+--------------------------------------------+----------------------+--------------------+-------------------------------------+----------------------+------------------+-----------+------------+------------+-----------+--------------+-------------------+-----------+-------------+-----------------+----------+-----------------------------------------+---------------------------------------+-------------------------------+------------+----------+----------+-------------------+
# 9      8.40
# 10     8.40
# 11     8.40
# 16     5.59
# 38     3.40
# 39     8.27
# 41     6.32
# 46    14.97
# 47    14.97
# 48    14.97
# Name: Power consumption, dtype: object
# Average power consumption for RTL: 9.369W

# %% [markdown]
# ### What is the best kind of design for YOLO models with similar complexities?

# %%
# # Filter the original dataset to see only models with "YOLO" in their name, equivalent model, or backbone
yoloDf = datapointsDf[datapointsDf["Model"].str.contains("YOLO", na=False) | datapointsDf["Equivalent model"].str.contains("YOLO", na=False) | datapointsDf["Backbone"].str.contains("YOLO", na=False)]

def convert_complexity_to_float(val: str):
    replacements = {"OP": "", "B": "e9", "G": "e6", "M": "e3", "K": "e3"}
    for old, new in replacements.items():
        val = val.replace(old, new)
    try:
        return float(val)
    except ValueError:
        return None

def filter_complexity(df: pd.DataFrame, threshold: float) -> pd.DataFrame:
    result_df = df.copy()
    result_df["clean_complexity"] = result_df["Complexity"].apply(
        lambda x: convert_complexity_to_float(x)
    )
    result_df.dropna(subset=["clean_complexity"], inplace=True)
    return result_df[result_df["clean_complexity"] > threshold]

filteredDf = filter_complexity(yoloDf, 1e6)
print_pretty_df(filteredDf.sort_values(by="Implementation"))
# Out:
# +----+------------------------------------------+-----------------+------------------+----------------+----------+------------------------------------+------------------+-------------------------+------------------------------+----------------------+------------------+-----------+----------+------------+-----------+--------------+-------------------+-----------+------------+-----------------+----------+------------------------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+------------------+
# |    |             BBT Citation Key             |      Model      | Equivalent model |    Backbone    | Modality |              Dataset               |       Task       |       Application       |            Board             |    Implementation    | Publication year |  Latency  |   FPS    | Task score | Footprint |  Throughput  | Power consumption | Frequency | Complexity |     Design      |  Memory  |          Precision           |             Optimizations             |          FPGA Util          | DPU Config | DPU Core | DPU Util | DPU Optimizations | clean_complexity |
# +----+------------------------------------------+-----------------+------------------+----------------+----------+------------------------------------+------------------+-------------------------+------------------------------+----------------------+------------------+-----------+----------+------------+-----------+--------------+-------------------+-----------+------------+-----------------+----------+------------------------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+------------------+
# | 24 |   zhangFPGAImplementationCNNbased2021a   | Improved YOLOv2 |      YOLOv2      |   Darknet19    |   RGB    |    DOTAv1.0 {Object Detection}     | Object detection |         Diverse         |    Zynq 7000 (XC7Z035) {}    |  RTL design (VHDL)   |       2021       |  3400 ms  |          | 67.32% mAP |           | 111.50 GOP/s |      5.96 W       |  200 MHz  |  379G OP   | Various Kernels | Off-chip | Mixed (Fixed 8 and Float 32) | ['Advanced Dataflow', 'Multiple PEs'] |   Low (21% DSP, 74% BRAM)   |            |          |          |        []         |   379000000.0    |
# | 36 | yanAutomaticDeploymentConvolutional2022a | Improved YOLOv2 |      YOLOv2      |   Darknet19    |   RGB    |    DOTAv1.0 {Object Detection}     | Object detection |         Diverse         |  Artix-7 (XC7A200T) {AC701}  |  RTL design (VHDL)   |       2022       | 17120 ms  |          | 67.30% mAP | 49.40 MB  | 22.17 GOP/s  |      3.41 W       |  200 MHz  | 379.55G OP | Various Kernels | Off-chip |          Fixed (8)           | ['Advanced Dataflow', 'Multiple PEs'] |   Low (12% DSP, 29% BRAM)   |            |          |          |        []         |   379550000.0    |
# | 46 |  niAlgorithmHardwareCoOptimization2023   | Improved YOLOv2 |      YOLOv2      |   Darknet19    |   RGB    |    DOTAv1.0 {Object Detection}     | Object detection |         Diverse         | Virtex-7 (XC7VX690T) {VC709} | RTL design (Verilog) |       2023       | 981.4 ms  |          | 67.30% mAP | 49.40 MB  |  387 GOP/s   |      14.97 W      |  200 MHz  | 379.55G OP | Various Kernels | Off-chip | Mixed width (Fixed 32 and 8) |           ['Multiple PEs']            |   Low (23% DSP, 54% BRAM)   |            |          |          |        []         |   379550000.0    |
# | 64 |    yangLightweightDetectionMethod2023    |   Ghost-YOLOS   |      YOLOv3      |    GhostNet    |   RGB    |    DOTAv1.0 {Object Detection}     | Object detection |         Diverse         |    Zynq 7000 (XC7Z020) {}    | RTL design (Verilog) |       2023       |  320 ms   |          | 62.58% mAP | 12.60 MB  | 29.53 GOP/s  |      2.98 W       |  150 MHz  |  8.41G OP  | Model Specific  | Off-chip |          Fixed (16)          |    ['Multiple PEs', 'Unclear/Bad']    | Average (58% DSP, 60% BRAM) |            |          |          |        []         |    8410000.0     |
# | 2  |  nguyenFPGASoCImplementationYOLOv42024   |     YOLOv4      |      YOLOv4      |   Darknet53    |   RGB    | UAV RGB (cust.) {Object Detection} | Object detection | Flying-object detection | Zynq US+ (XCZU7EV) {ZCU104}  |    Vitis AI (N/A)    |       2024       | 107.94 ms | 17.9 FPS | 83.7% mAP  |  245 MB   |              |      30.1 W       |  100 MHz  | 105.9G OP  |                 |          |          Fixed (8)           |                  []                   |             N/A             |    N/A     |    2     |   N/A    |      ['N/A']      |   105900000.0    |
# | 3  |  nguyenFPGASoCImplementationYOLOv42024   | YOLOv4-tiny 3L  |      YOLOv4      | Darknet53-tiny |   RGB    | UAV RGB (cust.) {Object Detection} | Object detection | Flying-object detection | Zynq US+ (XCZU7EV) {ZCU104}  |    Vitis AI (N/A)    |       2024       | 19.18 ms  | 125 FPS  | 72.24% mAP | 24.10 MB  |              |      26.40 W      |  100 MHz  | 15.32G OP  |                 |          |          Fixed (8)           |                  []                   |             N/A             |    N/A     |    2     |   N/A    |      ['N/A']      |    15320000.0    |
# +----+------------------------------------------+-----------------+------------------+----------------+----------+------------------------------------+------------------+-------------------------+------------------------------+----------------------+------------------+-----------+----------+------------+-----------+--------------+-------------------+-----------+------------+-----------------+----------+------------------------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+------------------+

# %% [markdown]
# ### What the best study on a DOTAv1.0, DIOR, or UP?

# %%
# Filter experiments that use the "University" dataset
datasetDf = datapointsDf[datapointsDf["Dataset"].str.contains("DIOR", na=False)] #NWPU-RE
print_pretty_df(datasetDf.sort_values(by="Publication year"))# Filter experiments that use the "University" dataset
# Out:
# +----+----------------------------------------+--------------------+------------------+-------------+----------+-------------------------+------------------+-------------+-----------------------------+-----------------+------------------+---------+-----------+------------+-----------+------------+-------------------+-----------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+-------------------+
# |    |            BBT Citation Key            |       Model        | Equivalent model |  Backbone   | Modality |         Dataset         |       Task       | Application |            Board            | Implementation  | Publication year | Latency |    FPS    | Task score | Footprint | Throughput | Power consumption | Frequency | Complexity | Design | Memory | Precision | Optimizations |          FPGA Util          | DPU Config | DPU Core | DPU Util | DPU Optimizations |
# +----+----------------------------------------+--------------------+------------------+-------------+----------+-------------------------+------------------+-------------+-----------------------------+-----------------+------------------+---------+-----------+------------+-----------+------------+-------------------+-----------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+-------------------+
# | 20 | zhaoHardwareAccelerationSatellite2023a | YOLOv4-MobileNetv3 |      YOLOv4      | MobileNetv3 |   RGB    | DIOR {Object Detection} | Object detection |   Diverse   |  Zynq US+ (XCK26) {KV260}   | Vitis AI (v2.5) |       2023       |         | 48.14 FPS | 82.61% mAP |  5.69 MB  |            |      7.20 W       |  200 MHz  |            |        |        | Fixed (8) |      []       | Average (59% DSP, N/A BRAM) |   B4096    |   N/A    |   N/A    |      ['N/A']      |
# | 27 |       liEdgeRealtimeObject2023a        |      RFA-YOLO      |      YOLOv4      | MobileNeXt  |   RGB    | DIOR {Object Detection} | Object detection |   Diverse   | Zynq US+ (XCZU7EV) {ZCU104} | Vitis AI (N/A)  |       2023       |         | 27.97 FPS | 64.85% mAP | 24.75 MB  |            |      15.82 W      |  200 MHz  |            |        |        | Fixed (8) |      []       |             N/A             |   B4096    |   N/A    |   N/A    |      ['N/A']      |
# +----+----------------------------------------+--------------------+------------------+-------------+----------+-------------------------+------------------+-------------+-----------------------------+-----------------+------------------+---------+-----------+------------+-----------+------------+-------------------+-----------+------------+--------+--------+-----------+---------------+-----------------------------+------------+----------+----------+-------------------+

# %%
taskDf = datapointsDf[datapointsDf["Task"].str.contains("Pixel", na=False)] #  | datapointsDf["Application"].str.startswith("Ship", na=False)
print_pretty_df(taskDf.sort_values(by="Application"))
print(len(taskDf))
print(datapointsDf["Application"].value_counts())
# Out:
# +----+-----------------------------------------+---------------------------+------------------+----------+----------------+--------------------------------------------+----------------------+--------------------------------------+-------------------------------------+----------------------+------------------+-----------+-----+------------+-----------+-------------+-------------------+-----------+-------------+--------------------+----------+------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+
# |    |            BBT Citation Key             |           Model           | Equivalent model | Backbone |    Modality    |                  Dataset                   |         Task         |             Application              |                Board                |    Implementation    | Publication year |  Latency  | FPS | Task score | Footprint | Throughput  | Power consumption | Frequency | Complexity  |       Design       |  Memory  | Precision  |             Optimizations             |          FPGA Util          | DPU Config | DPU Core | DPU Util | DPU Optimizations |
# +----+-----------------------------------------+---------------------------+------------------+----------+----------------+--------------------------------------------+----------------------+--------------------------------------+-------------------------------------+----------------------+------------------+-----------+-----+------------+-----------+-------------+-------------------+-----------+-------------+--------------------+----------+------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+
# | 18 |      boyleHighlevelFPGADesign2023a      |    Deep Belief Network    |       RBM        |          |      HSI       | Airport-Beach-Urban {Pixel classification} | Pixel classification |          Anomaly detection           |     Zynq US+ (XCZU7EV) {ZCU104}     |     HLS (Vitis)      |       2023       |  5.4 ms   |     |            |           |             |                   |  250 MHz  |             | Algorithm Specific | On-chip  | Float (32) |                ['N/A']                |   Low (10% DSP, 0% BRAM)    |            |          |          |        []         |
# | 32 |   torresCombinedWeightlessNeural2020    | Weightless Neural Systems |       WNS        |          |      RGB       |   UAV RGB (cust.) {Pixel classification}   | Pixel classification |       Deforestation detection        |       Zynq 7000 (XC7Z020) {}        |         N/A          |       2020       |           |     |  90.0% OA  |           |             |                   |           |             |        N/A         | On-chip  |  Original  |                ['N/A']                |             N/A             |            |          |          |        []         |
# | 4  | yahiaouiParallelizationFuzzyARTMAP2017a |         BRAM_DSP          |   Fuzzy ARTMAP   |          | RGB + infrared |  ALSAT-2A (cust.) {Pixel classification}   | Pixel classification |          Landcover/Land use          |      Virtex-6 (XC6VLX240T) {}       |  RTL design (VHDL)   |       2017       | 21.28 us  |     |  94.8% OA  |           |             |       4.8W        |  192 MHz  |             | Algorithm Specific | On-chip  | Fixed (8)  |           ['Multiple PEs']            |   Low (91% DSP,52% BRAM)    |            |          |          |        []         |
# | 5  | yahiaouiParallelizationFuzzyARTMAP2017a |          LUT_MUL          |   Fuzzy ARTMAP   |          | RGB + infrared |  ALSAT-2A (cust.) {Pixel classification}   | Pixel classification |          Landcover/Land use          |      Virtex-6 (XC6VLX240T) {}       |  RTL design (VHDL)   |       2017       | 21.28 us  |     |  94.8% OA  |           |             |       4.5W        |  189 MHz  |             | Algorithm Specific | On-chip  | Fixed (8)  |           ['Multiple PEs']            |    Low (0% DSP,0% BRAM)     |            |          |          |        []         |
# | 9  |         heConfigurable2D3D2023a         |          2D CNN           |       CNN        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 0.097 ms* |     | 98.24% OA  |  1.20 MB  | 7.07 GOP/s  |      8.40 W       |  100 MHz  |  0.684M OP  |  Various Kernels   | Off-chip | Fixed (8)  | ['Advanced Dataflow', 'Multiple PEs'] |  Low (22.5% DSP, 71% BRAM)  |            |          |          |        []         |
# | 10 |         heConfigurable2D3D2023a         |          3D CNN           |       CNN        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 1.11 ms*  |     | 94.09% OA  |  0.12 MB  | 3.81 GOP/s  |      8.40 W       |  100 MHz  |  4.231M OP  |  Various Kernels   | Off-chip | Fixed (8)  | ['Advanced Dataflow', 'Multiple PEs'] |  Low (27.9% DSP, 76% BRAM)  |            |          |          |        []         |
# | 11 |         heConfigurable2D3D2023a         |         HybridSN          |       CNN        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          | Zynq US+ (XCZU15EG) {Alinx AXU15EG} |   RTL design (N/A)   |       2023       | 7.71 ms*  |     |  100% OA   | 20.50 MB  | 13.18 GOP/s |      8.40 W       |  100 MHz  | 101.642M OP |  Various Kernels   | Off-chip | Fixed (8)  | ['Advanced Dataflow', 'Multiple PEs'] | Average (37% DSP, 80% BRAM) |            |          |          |        []         |
# | 15 |    shibiOnboardTargetDetection2021a     |           LPDBL           |        ML        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          |       Virtex-7 (XC7VX690T) {}       |  RTL design (VHDL)   |       2021       |           |     |            |           |             |                   |  200 MHz  |             | Algorithm Specific | On-chip  |  Original  |           ['Multiple PEs']            |   Low (14% DSP, 15% BRAM)   |            |          |          |        []         |
# | 21 |  chellaswamyFPGAbasedRemoteTarget2024   |          SAM-GNN          |       GNN        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          |       Virtex-7 (XC7VX690T) {}       |  RTL design (VHDL)   |       2024       |           |     | 95.05% OA  |           |             |                   |  200 MHz  |             | Algorithm Specific | Off-chip |  Original  |           ['Multiple PEs']            |   Low (13% DSP, 14% BRAM)   |            |          |          |        []         |
# | 56 |       gyaneshwarRealtimeSCSUP2022       |         CAG-SC2S          |        ML        |          |      HSI       |      AVIRIS-NG {Pixel classification}      | Pixel classification |          Landcover/Land use          |    Artix-7 (XC7A35T) {Arty-35T}     |   RTL design (XSG)   |       2022       | 5.27 us*  |     | 98.30% OA  |           |             |      0.31 W       | 70.40 MHz |             |   Model Specific   |   N/A    | Fixed (32) |   ['Systolic array', 'Unclear/Bad']   |  High (93% DSP, 21% BRAM))  |            |          |          |        []         |
# | 57 |       gyaneshwarRealtimeSCSUP2022       |         CAL-SC2S          |        ML        |          |      HSI       |      AVIRIS-NG {Pixel classification}      | Pixel classification |          Landcover/Land use          |    Artix-7 (XC7A35T) {Arty-35T}     |   RTL design (XSG)   |       2022       | 5.70 us*  |     | 99.69% OA  |           |             |      0.36 W       | 65.20 MHz |             |   Model Specific   |   N/A    | Fixed (32) |   ['Systolic array', 'Unclear/Bad']   |  High (96% DSP, 25% BRAM))  |            |          |          |        []         |
# | 58 |       gyaneshwarRealtimeSCSUP2022       |            SVM            |        ML        |          |      HSI       |      AVIRIS-NG {Pixel classification}      | Pixel classification |          Landcover/Land use          |    Artix-7 (XC7A35T) {Arty-35T}     |   RTL design (XSG)   |       2022       | 5.12 us*  |     | 20.71% OA  |           |             |      0.22 W       | 72.40 MHz |             |   Model Specific   |   N/A    | Fixed (32) |   ['Systolic array', 'Unclear/Bad']   | Average (49% DSP, 6% BRAM)) |            |          |          |        []         |
# | 59 |   martinsRealtimeSVMbasedHardware2024   |            SVM            |        ML        |          |      HSI       | University of Pavia {Pixel classification} | Pixel classification |          Landcover/Land use          |       Zynq 7000 (XC7Z020) {}        |  RTL design (VHDL)   |       2024       | 0.11 ms*  |     | 82.48% AA  |           |             |                   |  200 MHz  |             |   Model Specific   | On-chip  |  Original  |            ['Unclear/Bad']            | Average (38% DSP, N/A BRAM) |            |          |          |        []         |
# | 8  |     fraczekEmbeddedVisionSystem2018     |       Decision Tree       |        ML        |          |      RGB       |   UAV RGB (cust.) {Pixel classification}   | Pixel classification | Safe UAV landing site identification |    Zynq 7000 (XC7Z020) {Arty Z7}    | RTL design (Verilog) |       2018       |  300 ms*  |     |  92.1% OA  |           |             |      3.50 W       |           |             | Algorithm Specific | On-chip  | Fixed (8)  |                ['N/A']                |   Low (10% DSP, 86% BRAM)   |            |          |          |        []         |
# +----+-----------------------------------------+---------------------------+------------------+----------+----------------+--------------------------------------------+----------------------+--------------------------------------+-------------------------------------+----------------------+------------------+-----------+-----+------------+-----------+-------------+-------------------+-----------+-------------+--------------------+----------+------------+---------------------------------------+-----------------------------+------------+----------+----------+-------------------+
# 14
# Application
# Landcover/Land use                         17
# Diverse                                     9
# Cloud coverage                              8
# Military targets identification             5
# Ship identification                         5
# Flying-object detection                     5
# Urban areas                                 4
# Ship detection                              3
# Aircraft detection                          2
# Railway track fastener defect detection     1
# Air Quality Monitoring                      1
# Anomaly detection                           1
# Deforestation detection                     1
# UAV obstacles detection                     1
# Oil spills feature extraction               1
# Safe UAV landing site identification        1
# General                                     1
# Name: count, dtype: int64

# %% [markdown]
# ### Datasets, RS Applications and ML formulations
#
# In our reporting method, each experiment is performed on a unique Dataset (i.e., we selected the most relevant/common dataset when authors reported results on different one).
# Each dataset is used (or even built) for a specific Remote Sensing application which is formulated as a Machine Learning problem or task.
#
# The `Application` tag is no exact science and was kept in order to give some context.

# %%
# ----- Print all unique ML problem formulations -----
mlTaskList = datapointsDf["Task"].unique()
print(mlTaskList)

# ----- Group by "Dataset" -----
DatasetCount = datapointsDf["Dataset"].value_counts()
print(DatasetCount)

# ----- Group by "Application" -----
applicationCount = datapointsDf["Application"].value_counts()
print(applicationCount)
# Out:
# ['Classification' 'Object detection' 'Pixel classification' 'Regression'
#  'Segmentation']
# Dataset
# University of Pavia {Pixel classification}           6
# MSTAR {Classification}                               5
# DOTAv1.0 {Object Detection}                          4
# NWPU-RESISC45 {Classification}                       4
# Potsdam {Segmentation}                               4
# SSDD {Object Detection}                              3
# AVIRIS-NG {Pixel classification}                     3
# PennSyn2Real {Object Detection}                      3
# UAV RGB (cust.) {Object Detection}                   3
# Landsat-8 (cust.) {Classification}                   2
# L8 Biome {Classification}                            2
# RGB (cust.) {Classification}                         2
# DIOR {Object Detection}                              2
# MASATI {Classification}                              2
# ALOS-2 (cust.) {Classification}                      2
# UAV RGB (cust.) {Classification}                     2
# UAV RGB (cust.) {Pixel classification}               2
# ALSAT-2A (cust.) {Pixel classification}              2
# Airbus {Object Detection}                            1
# UC-Merced Land Use {Classification}                  1
# DAC 2018 {Object Detection}                          1
# Kaggle SSI {Classification}                          1
# NWPU VHR-10 {Object Detection}                       1
# Sentinel-2 (cust.) {Classification}                  1
# FastenerDataset (cust.) {Object Detection}           1
# Google Earth Studio RGB (sim.) {Object Detection}    1
# UAV RGB+MMW (cust.) {Object Detection}               1
# Airport-Beach-Urban {Pixel classification}           1
# 38-Cloud {Segmentation}                              1
# SAR (sim.) {Regression}                              1
# Landsat-8-OLI (cust.) {Segmentation}                 1
# Name: count, dtype: int64
# Application
# Landcover/Land use                         17
# Diverse                                     9
# Cloud coverage                              8
# Military targets identification             5
# Ship identification                         5
# Flying-object detection                     5
# Urban areas                                 4
# Ship detection                              3
# Aircraft detection                          2
# Railway track fastener defect detection     1
# Air Quality Monitoring                      1
# Anomaly detection                           1
# Deforestation detection                     1
# UAV obstacles detection                     1
# Oil spills feature extraction               1
# Safe UAV landing site identification        1
# General                                     1
# Name: count, dtype: int64

# %% [markdown]
# Print unique associations of Task and applications

# %%
print_pretty_df(datapointsDf.sort_values(by="Board")[["Board", "Implementation", "Model", "Equivalent model", "Backbone", "Task", "Application"]])
# Out:
# +----+------------------------------------------------+----------------------+-------------------------------+------------------+----------------+----------------------+-----------------------------------------+
# |    |                     Board                      |    Implementation    |             Model             | Equivalent model |    Backbone    |         Task         |               Application               |
# +----+------------------------------------------------+----------------------+-------------------------------+------------------+----------------+----------------------+-----------------------------------------+
# | 55 |                Alveo (U280) {}                 |      HLS (N/A)       |              GNN              |       GNN        |                |    Classification    |     Military targets identification     |
# | 36 |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |   Object detection   |                 Diverse                 |
# | 35 |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |        Improved VGG16         |       CNN        |     VGG16      |    Classification    |           Landcover/Land use            |
# | 58 |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |              SVM              |        ML        |                | Pixel classification |           Landcover/Land use            |
# | 57 |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |           CAL-SC2S            |        ML        |                | Pixel classification |           Landcover/Land use            |
# | 56 |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |           CAG-SC2S            |        ML        |                | Pixel classification |           Landcover/Land use            |
# | 0  |              Artix-7 (XC7A35T) {}              |  RTL design (VHDL)   |              CNN              |       CNN        |                |    Classification    |             Cloud coverage              |
# | 17 |             Cyclone V (5CSXC6) {}              |      HLS (VGT)       |            C-FCN++            |       CNN        |                |     Segmentation     |             Cloud coverage              |
# | 23 |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |        MobileNetv1Lite        |       CNN        |  MobileNetv1   |    Classification    |           Ship identification           |
# | 22 |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |          AlexNetLite          |     AlexNet      |    AlexNet     |    Classification    |           Ship identification           |
# | 6  |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |          LeNet-5 f32          |     LeNet-5      |    LeNet-5     |    Classification    |     Military targets identification     |
# | 7  |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |          LeNet-5 i8           |     LeNet-5      |    LeNet-5     |    Classification    |     Military targets identification     |
# | 19 |             Kintex-7 (XC7K325T) {}             |         N/A          |            LeNet-5            |     LeNet-5      |    LeNet-5     |    Classification    |     Military targets identification     |
# | 13 | Spartan-3A (XC3SD1800A) {Avnet Spartan-3A DSP} |  RTL design (VHDL)   |              MLP              |       MLP        |                |    Classification    |           Landcover/Land use            |
# | 65 |            Virtex-6 (XC6VLX240T) {}            | RTL design (Verilog) | Roller Dung Bettle Clustering |        ML        |                |     Segmentation     |                 General                 |
# | 5  |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |            LUT_MUL            |   Fuzzy ARTMAP   |                | Pixel classification |           Landcover/Land use            |
# | 4  |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |           BRAM_DSP            |   Fuzzy ARTMAP   |                | Pixel classification |           Landcover/Land use            |
# | 45 |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |           CNN6@1.6            |      YOLOv2      |   SqueezeNet   |   Object detection   |             Ship detection              |
# | 41 |          Virtex-7 (XC7VX690T) {VC709}          |  RTL design (VHDL)   |            Q-IORN             |       CNN        |     VGG16      |    Classification    |           Landcover/Land use            |
# | 48 |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |             VGG16             |       CNN        |     VGG16      |    Classification    |           Landcover/Land use            |
# | 43 |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |           CNN2@0.7            |      YOLOv2      |  MobileNetv1   |   Object detection   |             Ship detection              |
# | 47 |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |           ResNet-34           |       CNN        |   ResNet-34    |    Classification    |           Landcover/Land use            |
# | 46 |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |   Object detection   |                 Diverse                 |
# | 44 |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |           CNN4@0.7            |      YOLOv2      |  MobileNetv2   |   Object detection   |             Ship detection              |
# | 39 |            Virtex-7 (XC7VX690T) {}             |   RTL design (N/A)   |             A2NN              |       CNN        |     VGG11      |    Classification    |           Landcover/Land use            |
# | 15 |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |             LPDBL             |        ML        |                | Pixel classification |           Landcover/Land use            |
# | 21 |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |            SAM-GNN            |       GNN        |                | Pixel classification |           Landcover/Land use            |
# | 8  |         Zynq 7000 (XC7Z020) {Arty Z7}          | RTL design (Verilog) |         Decision Tree         |        ML        |                | Pixel classification |  Safe UAV landing site identification   |
# | 54 |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |     HLS (Vivado)     |              CNN              |       CNN        |                |   Object detection   |                 Diverse                 |
# | 14 |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         FINN         |              CNN              |       CNN        |                |    Classification    |           Ship identification           |
# | 12 |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         N/A          |              MLP              |       MLP        |                |      Regression      |      Oil spills feature extraction      |
# | 34 |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       CloudSatNet-1 Q4        |       CNN        |                |    Classification    |             Cloud coverage              |
# | 33 |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       CloudSatNet-1 Q2        |       CNN        |                |    Classification    |             Cloud coverage              |
# | 59 |             Zynq 7000 (XC7Z020) {}             |  RTL design (VHDL)   |              SVM              |        ML        |                | Pixel classification |           Landcover/Land use            |
# | 32 |             Zynq 7000 (XC7Z020) {}             |         N/A          |   Weightless Neural Systems   |       WNS        |                | Pixel classification |         Deforestation detection         |
# | 64 |             Zynq 7000 (XC7Z020) {}             | RTL design (Verilog) |          Ghost-YOLOS          |      YOLOv3      |    GhostNet    |   Object detection   |                 Diverse                 |
# | 25 |             Zynq 7000 (XC7Z020) {}             |         N/A          |        Lightweight CNN        |       CNN        |   ResNet-18    |   Object detection   |         UAV obstacles detection         |
# | 24 |             Zynq 7000 (XC7Z035) {}             |  RTL design (VHDL)   |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |   Object detection   |                 Diverse                 |
# | 40 |          Zynq 7000 (XC7Z045) {ZC706}           |  RTL design (VHDL)   |          HO-ShipNet           |       CNN        |                |    Classification    |           Ship identification           |
# | 28 |          Zynq 7000 (XC7Z045) {ZC706}           |         FINN         |              BNN              |       CNN        |                |    Classification    |           Ship identification           |
# | 26 |             Zynq 7000 (XC7Z100) {}             | RTL design (Verilog) |           CBFF-SSD            |       SSD        |  MobileNetv1   |   Object detection   |                 Diverse                 |
# | 1  |           Zynq 7000 (Z7020) {ZC702}            |     HLS (Vivado)     |      TriCloudNet + U-Net      |       CNN        |   SqueezeNet   |    Classification    |             Cloud coverage              |
# | 20 |            Zynq US+ (XCK26) {KV260}            |   Vitis AI (v2.5)    |      YOLOv4-MobileNetv3       |      YOLOv4      |  MobileNetv3   |   Object detection   |                 Diverse                 |
# | 11 |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |           HybridSN            |       CNN        |                | Pixel classification |           Landcover/Land use            |
# | 9  |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |            2D CNN             |       CNN        |                | Pixel classification |           Landcover/Land use            |
# | 10 |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |            3D CNN             |       CNN        |                | Pixel classification |           Landcover/Land use            |
# | 42 |          Zynq US+ (XCZU19EG) {KV260}           |    Vitis AI (N/A)    |             ETAUS             |       CNN        |   ResNet-50    |    Classification    |         Air Quality Monitoring          |
# | 51 |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |           SSD 1.0x            |       SSD        |     VGG16      |   Object detection   |         Flying-object detection         |
# | 49 |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |           SSD 0.25x           |       SSD        |     VGG16      |   Object detection   |         Flying-object detection         |
# | 50 |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |           SSD 0.5x            |       SSD        |     VGG16      |   Object detection   |         Flying-object detection         |
# | 16 |          Zynq US+ (XCZU3EG) {Ultra96}          |   RTL design (N/A)   |           AP2D-Net            |       CNN        |                |   Object detection   |                 Diverse                 |
# | 60 |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |             ENet              |       CNN        |                |     Segmentation     |               Urban areas               |
# | 61 |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |            ESPNet             |       CNN        |                |     Segmentation     |               Urban areas               |
# | 62 |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |              FPN              |       CNN        |                |     Segmentation     |               Urban areas               |
# | 63 |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |             U-Net             |       CNN        |                |     Segmentation     |               Urban areas               |
# | 52 |          Zynq US+ (XCZU7EV) {ZCU104}           |      HLS (N/A)       |              GNN              |       GNN        |                |    Classification    |     Military targets identification     |
# | 37 |          Zynq US+ (XCZU7EV) {ZCU104}           |   Vitis AI (v1.4)    |     Improved YOLOv4-tiny      |   YOLOv4-tiny    |  CSPDarknet53  |   Object detection   | Railway track fastener defect detection |
# | 18 |          Zynq US+ (XCZU7EV) {ZCU104}           |     HLS (Vitis)      |      Deep Belief Network      |       RBM        |                | Pixel classification |            Anomaly detection            |
# | 3  |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |        YOLOv4-tiny 3L         |      YOLOv4      | Darknet53-tiny |   Object detection   |         Flying-object detection         |
# | 2  |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |            YOLOv4             |      YOLOv4      |   Darknet53    |   Object detection   |         Flying-object detection         |
# | 27 |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |           RFA-YOLO            |      YOLOv4      |   MobileNeXt   |   Object detection   |                 Diverse                 |
# | 38 |          Zynq US+ (XCZU7EV) {ZCU106}           |  RTL design (VHDL)   |          CloudScout           |       CNN        |                |    Classification    |             Cloud coverage              |
# | 53 |          Zynq US+ (XCZU9EG) {ZCU102}           |     HLS (MATLAB)     |       ResNet-18+YOLOv2        |      YOLOv2      |   ResNet-18    |   Object detection   |           Aircraft detection            |
# | 30 |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |           ResNet-50           |       CNN        |   ResNet-50    |    Classification    |             Cloud coverage              |
# | 31 |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |            SICNet             |       CNN        |                |    Classification    |             Cloud coverage              |
# | 29 |             Zynq US+ (XCZU9EG) {}              |      HLS (N/A)       |        Improved YOLOv3        |      YOLOv3      |   DarkNet53    |   Object detection   |           Aircraft detection            |
# +----+------------------------------------------------+----------------------+-------------------------------+------------------+----------------+----------------------+-----------------------------------------+

# %%
# Print unique associations of Task and applications
taskApplicationPairs = datapointsDf[["Task", "Modality", "Application"]].value_counts()
print(taskApplicationPairs.sort_index())
# Out:
# Task                  Modality        Application
# Classification        HSI             Air Quality Monitoring                     1
#                                       Cloud coverage                             1
#                       RGB             Cloud coverage                             6
#                                       Landcover/Land use                         6
#                                       Ship identification                        3
#                       SAR             Military targets identification            5
#                                       Ship identification                        2
# Object detection      RGB             Aircraft detection                         2
#                                       Diverse                                    9
#                                       Flying-object detection                    5
#                                       Railway track fastener defect detection    1
#                       RGB + MMW       UAV obstacles detection                    1
#                       SAR             Ship detection                             3
# Pixel classification  HSI             Anomaly detection                          1
#                                       Landcover/Land use                         9
#                       RGB             Deforestation detection                    1
#                                       Safe UAV landing site identification       1
#                       RGB + infrared  Landcover/Land use                         2
# Regression            SAR             Oil spills feature extraction              1
# Segmentation          RGB             Cloud coverage                             1
#                                       General                                    1
#                                       Urban areas                                4
# Name: count, dtype: int64

# %% [markdown]
# ## Deeper analysis of common dataset and tasks among the dataframe
#
# I try to check how many models (and papers) use the same datasets

# %%
# For the first 4 datasets, print each model's name, the corresponding article research key and their metric
for dataset in DatasetCount.index[:4]:
    print(f"\n{b}{dataset}{e} dataset:")
    for index, row in datapointsDf.iterrows():
        if row["Dataset"] == dataset:
            print(
                f"    - {r}{row['Model']}{e} from {b}{row['BBT Citation Key']}{e} with board: {r}{row['Board']}{e} ({b}{row['Implementation']}{e}):"
            )
            print(
                f"        Score: {g}{row['Task score']}{e}, Size: {g}{row['Footprint']}{e}, Latency: {g}{row['Latency']}{e}, Throughput: {g}{row['Throughput']}{e}, Power: {g}{row['Power consumption']}{e}"
            )
# Out:
# University of Pavia {Pixel classification} dataset:
#     - 2D CNN from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#         Score: 98.24% OA, Size: 1.20 MB, Latency: 0.097 ms*, Throughput: 7.07 GOP/s, Power: 8.40 W
#     - 3D CNN from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#         Score: 94.09% OA, Size: 0.12 MB, Latency: 1.11 ms*, Throughput: 3.81 GOP/s, Power: 8.40 W
#     - HybridSN from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#         Score: 100% OA, Size: 20.50 MB, Latency: 7.71 ms*, Throughput: 13.18 GOP/s, Power: 8.40 W
#     - LPDBL from shibiOnboardTargetDetection2021a with board: Virtex-7 (XC7VX690T) {} (RTL design (VHDL)):
#         Score: , Size: , Latency: , Throughput: , Power:
#     - SAM-GNN from chellaswamyFPGAbasedRemoteTarget2024 with board: Virtex-7 (XC7VX690T) {} (RTL design (VHDL)):
#         Score: 95.05% OA, Size: , Latency: , Throughput: , Power:
#     - SVM from martinsRealtimeSVMbasedHardware2024 with board: Zynq 7000 (XC7Z020) {} (RTL design (VHDL)):
#         Score: 82.48% AA, Size: , Latency: 0.11 ms*, Throughput: , Power:
#
# MSTAR {Classification} dataset:
#     - LeNet-5 f32 from weiFPGABasedHybridTypeImplementation2019 with board: Kintex-7 (XC7K325T) {KC705} (RTL design (N/A)):
#         Score: 98.76% OA, Size: 6.64 MB, Latency: 2.29 ms, Throughput: , Power:
#     - LeNet-5 i8 from weiFPGABasedHybridTypeImplementation2019 with board: Kintex-7 (XC7K325T) {KC705} (RTL design (N/A)):
#         Score: 97.77% OA, Size: 1.66 MB, Latency: 2.29 ms, Throughput: , Power:
#     - LeNet-5 from chenHardwareImplementationConvolutional2020 with board: Kintex-7 (XC7K325T) {} (N/A):
#         Score: 98.18% OA, Size: , Latency: 2.29 ms, Throughput: , Power:
#     - GNN from zhangAccurateLowlatencyEfficient2022a with board: Zynq US+ (XCZU7EV) {ZCU104} (HLS (N/A)):
#         Score: 99.09% OA, Size: 0.96 MB, Latency: 0.105 ms, Throughput: , Power: 6.30 W
#     - GNN from zhangAcceleratingGNNbasedSAR2023 with board: Alveo (U280) {} (HLS (N/A)):
#         Score: , Size: , Latency: 27 ms, Throughput: 400 GOP/s, Power: 38.00 W
#
# DOTAv1.0 {Object Detection} dataset:
#     - Improved YOLOv2 from zhangFPGAImplementationCNNbased2021a with board: Zynq 7000 (XC7Z035) {} (RTL design (VHDL)):
#         Score: 67.32% mAP, Size: , Latency: 3400 ms, Throughput: 111.50 GOP/s, Power: 5.96 W
#     - Improved YOLOv2 from yanAutomaticDeploymentConvolutional2022a with board: Artix-7 (XC7A200T) {AC701} (RTL design (VHDL)):
#         Score: 67.30% mAP, Size: 49.40 MB, Latency: 17120 ms, Throughput: 22.17 GOP/s, Power: 3.41 W
#     - Improved YOLOv2 from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#         Score: 67.30% mAP, Size: 49.40 MB, Latency: 981.4 ms, Throughput: 387 GOP/s, Power: 14.97 W
#     - Ghost-YOLOS from yangLightweightDetectionMethod2023 with board: Zynq 7000 (XC7Z020) {} (RTL design (Verilog)):
#         Score: 62.58% mAP, Size: 12.60 MB, Latency: 320 ms, Throughput: 29.53 GOP/s, Power: 2.98 W
#
# NWPU-RESISC45 {Classification} dataset:
#     - Improved VGG16 from yanAutomaticDeploymentConvolutional2022a with board: Artix-7 (XC7A200T) {AC701} (RTL design (VHDL)):
#         Score: 88.08% OA, Size: 14.80 MB, Latency: 1780 ms, Throughput: 23.06 GOP/s, Power: 3.41 W
#     - Q-IORN from zhangEfficientFPGABasedImplementation2020 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (VHDL)):
#         Score: 88.31% OA, Size: 121.51 MB, Latency: 147.62 ms, Throughput: 209.60 GOP/s, Power: 6.32 W
#     - ResNet-34 from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#         Score: 92.81% OA, Size: 21.29 MB, Latency: 40.2 ms, Throughput: 182 GOP/s, Power: 14.97 W
#     - VGG16 from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#         Score: 91.90% OA, Size: 14.70 MB, Latency: 89.1 ms, Throughput: 344 GOP/s, Power: 14.97 W

# %% [markdown]
# ### Check common tasks

# %%
# For each Task, group by dataset and print each model name and backbones
MLTaskCount = datapointsDf["Task"].value_counts()
for task, value in MLTaskCount.items():
    print(f"\n{b}{task}{e} task (total: {value}):")
    nbItems = 0
    for dataset in DatasetCount.index:
        if dataset.split("{")[1][:-1].strip().upper() == task.upper():
            print(f"    {b}{dataset.split('{')[0].strip()}{e}:")
            for index, row in datapointsDf.iterrows():
                if row["Task"] == task and row["Dataset"] == dataset:
                    print(
                        f"        - {r}{row['Model']}{e} ({row['Equivalent model']}) [{y}{row['Backbone']}{e}] from {b}{row['BBT Citation Key']}{e} with board: {r}{row['Board']}{e} ({row['Implementation']}):"
                    )
                    print(
                        f"            Score: {g}{row['Task score']}{e}, Size: {g}{row['Footprint']}{e}, Latency: {g}{row['Latency']}{e}, Throughput: {g}{row['Throughput']}{e}, Power: {g}{row['Power consumption']}{e}"
                    )
                    nbItems += 1

    print(f"    Total: {nbItems}")
# Out:
# Classification task (total: 24):
#     MSTAR:
#         - LeNet-5 f32 (LeNet-5) [LeNet-5] from weiFPGABasedHybridTypeImplementation2019 with board: Kintex-7 (XC7K325T) {KC705} (RTL design (N/A)):
#             Score: 98.76% OA, Size: 6.64 MB, Latency: 2.29 ms, Throughput: , Power:
#         - LeNet-5 i8 (LeNet-5) [LeNet-5] from weiFPGABasedHybridTypeImplementation2019 with board: Kintex-7 (XC7K325T) {KC705} (RTL design (N/A)):
#             Score: 97.77% OA, Size: 1.66 MB, Latency: 2.29 ms, Throughput: , Power:
#         - LeNet-5 (LeNet-5) [LeNet-5] from chenHardwareImplementationConvolutional2020 with board: Kintex-7 (XC7K325T) {} (N/A):
#             Score: 98.18% OA, Size: , Latency: 2.29 ms, Throughput: , Power:
#         - GNN (GNN) [] from zhangAccurateLowlatencyEfficient2022a with board: Zynq US+ (XCZU7EV) {ZCU104} (HLS (N/A)):
#             Score: 99.09% OA, Size: 0.96 MB, Latency: 0.105 ms, Throughput: , Power: 6.30 W
#         - GNN (GNN) [] from zhangAcceleratingGNNbasedSAR2023 with board: Alveo (U280) {} (HLS (N/A)):
#             Score: , Size: , Latency: 27 ms, Throughput: 400 GOP/s, Power: 38.00 W
#     NWPU-RESISC45:
#         - Improved VGG16 (CNN) [VGG16] from yanAutomaticDeploymentConvolutional2022a with board: Artix-7 (XC7A200T) {AC701} (RTL design (VHDL)):
#             Score: 88.08% OA, Size: 14.80 MB, Latency: 1780 ms, Throughput: 23.06 GOP/s, Power: 3.41 W
#         - Q-IORN (CNN) [VGG16] from zhangEfficientFPGABasedImplementation2020 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (VHDL)):
#             Score: 88.31% OA, Size: 121.51 MB, Latency: 147.62 ms, Throughput: 209.60 GOP/s, Power: 6.32 W
#         - ResNet-34 (CNN) [ResNet-34] from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#             Score: 92.81% OA, Size: 21.29 MB, Latency: 40.2 ms, Throughput: 182 GOP/s, Power: 14.97 W
#         - VGG16 (CNN) [VGG16] from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#             Score: 91.90% OA, Size: 14.70 MB, Latency: 89.1 ms, Throughput: 344 GOP/s, Power: 14.97 W
#     Landsat-8 (cust.):
#         - CNN (CNN) [] from vitoloRealTimeOnboardSatellite2024 with board: Artix-7 (XC7A35T) {} (RTL design (VHDL)):
#             Score: 89.64% F1, Size: , Latency: , Throughput: 1.14 GOP/s, Power: 0.116 W
#         - TriCloudNet + U-Net (CNN) [SqueezeNet] from kimOnOrbitAICloud2024 with board: Zynq 7000 (Z7020) {ZC702} (HLS (Vivado)):
#             Score: 6.84% CRE, Size: 3.61 MB, Latency: 1028 ms, Throughput: , Power: 0.196 W
#     L8 Biome:
#         - CloudSatNet-1 Q2 (CNN) [] from pitonakCloudSatNet1FPGABasedHardwareAccelerated2022 with board: Zynq 7000 (XC7Z020) {Z-turn} (FINN):
#             Score: 83.41% OA, Size: 1.43 MB, Latency: , Throughput: , Power: 2.52 W
#         - CloudSatNet-1 Q4 (CNN) [] from pitonakCloudSatNet1FPGABasedHardwareAccelerated2022 with board: Zynq 7000 (XC7Z020) {Z-turn} (FINN):
#             Score: 87.42% OA, Size: 3.06 MB, Latency: , Throughput: , Power: 2.59 W
#     RGB (cust.):
#         - ResNet-50 (CNN) [ResNet-50] from upadhyayDesignImplementationCNNbased2024 with board: Zynq US+ (XCZU9EG) {ZCU102} (Vitis AI (N/A)):
#             Score: , Size: , Latency: 10.7 ms, Throughput: , Power:
#         - SICNet (CNN) [] from upadhyayDesignImplementationCNNbased2024 with board: Zynq US+ (XCZU9EG) {ZCU102} (Vitis AI (N/A)):
#             Score: 85.76% OA, Size: , Latency: 1.8 ms, Throughput: , Power:
#     MASATI:
#         - AlexNetLite (AlexNet) [AlexNet] from nerisFPGABasedImplementationCNN2022a with board: Kintex US (XCKU040) {KCU105} (HLS (Vitis)):
#             Score: 89% F1, Size: , Latency: , Throughput: , Power:
#         - MobileNetv1Lite (CNN) [MobileNetv1] from nerisFPGABasedImplementationCNN2022a with board: Kintex US (XCKU040) {KCU105} (HLS (Vitis)):
#             Score: 94% F1, Size: , Latency: , Throughput: , Power:
#     ALOS-2 (cust.):
#         - CNN (CNN) [] from hashimotoShipClassificationSAR2019a with board: Zynq 7000 (XC7Z020) {PYNQ-Z1} (FINN):
#             Score: 100% OA, Size: , Latency: 330 ms, Throughput: , Power:
#         - BNN (CNN) [] from myojinDetectingUncertainBNN2020 with board: Zynq 7000 (XC7Z045) {ZC706} (FINN):
#             Score: , Size: , Latency: 21.14 ms, Throughput: , Power:
#     UAV RGB (cust.):
#         - MLP (MLP) [] from matos-carvalhoStaticDynamicAlgorithms2019 with board: Spartan-3A (XC3SD1800A) {Avnet Spartan-3A DSP} (RTL design (VHDL)):
#             Score: 95.14% OA, Size: , Latency: , Throughput: , Power:
#         - ETAUS (CNN) [ResNet-50] from huangEdgeTrustworthyAI2024 with board: Zynq US+ (XCZU19EG) {KV260} (Vitis AI (N/A)):
#             Score: 86.38% F1, Size: , Latency: 107.8 ms, Throughput: 329.90 GOP/s, Power: 1.65 W
#     UC-Merced Land Use:
#         - A2NN (CNN) [VGG11] from zhangExtremelyPipelinedFPGAbased2023a with board: Virtex-7 (XC7VX690T) {} (RTL design (N/A)):
#             Score: 94.76% OA, Size: , Latency: 4.92 ms, Throughput: 3047 GOP/s, Power: 8.27 W
#     Kaggle SSI:
#         - HO-ShipNet (CNN) [] from ieracitanoExplainableEmbeddedNeural2024 with board: Zynq 7000 (XC7Z045) {ZC706} (RTL design (VHDL)):
#             Score: 93.44% F1, Size: , Latency: 1.01 ms, Throughput: , Power: 1.90 W
#     Sentinel-2 (cust.):
#         - CloudScout (CNN) [] from rapuanoFPGAbasedHardwareAccelerator2021a with board: Zynq US+ (XCZU7EV) {ZCU106} (RTL design (VHDL)):
#             Score: 92.0% OA, Size: 13.30 MB, Latency: 141.7 ms, Throughput: , Power: 3.40 W
#     Total: 24
#
# Object detection task (total: 21):
#     DOTAv1.0:
#         - Improved YOLOv2 (YOLOv2) [Darknet19] from zhangFPGAImplementationCNNbased2021a with board: Zynq 7000 (XC7Z035) {} (RTL design (VHDL)):
#             Score: 67.32% mAP, Size: , Latency: 3400 ms, Throughput: 111.50 GOP/s, Power: 5.96 W
#         - Improved YOLOv2 (YOLOv2) [Darknet19] from yanAutomaticDeploymentConvolutional2022a with board: Artix-7 (XC7A200T) {AC701} (RTL design (VHDL)):
#             Score: 67.30% mAP, Size: 49.40 MB, Latency: 17120 ms, Throughput: 22.17 GOP/s, Power: 3.41 W
#         - Improved YOLOv2 (YOLOv2) [Darknet19] from niAlgorithmHardwareCoOptimization2023 with board: Virtex-7 (XC7VX690T) {VC709} (RTL design (Verilog)):
#             Score: 67.30% mAP, Size: 49.40 MB, Latency: 981.4 ms, Throughput: 387 GOP/s, Power: 14.97 W
#         - Ghost-YOLOS (YOLOv3) [GhostNet] from yangLightweightDetectionMethod2023 with board: Zynq 7000 (XC7Z020) {} (RTL design (Verilog)):
#             Score: 62.58% mAP, Size: 12.60 MB, Latency: 320 ms, Throughput: 29.53 GOP/s, Power: 2.98 W
#     SSDD:
#         - CNN2@0.7 (YOLOv2) [MobileNetv1] from yangAlgorithmHardwareCodesign2022 with board: Virtex-7 (XC7VX690T) {VC709} (HLS (Vitis)):
#             Score: 94% AP, Size: 0.09 MB, Latency: 0.7 ms, Throughput: 298 GOP/s, Power: 5.80 W
#         - CNN4@0.7 (YOLOv2) [MobileNetv2] from yangAlgorithmHardwareCodesign2022 with board: Virtex-7 (XC7VX690T) {VC709} (HLS (Vitis)):
#             Score: 93.3% AP, Size: 0.11 MB, Latency: 0.7 ms, Throughput: 366 GOP/s, Power: 6.60 W
#         - CNN6@1.6 (YOLOv2) [SqueezeNet] from yangAlgorithmHardwareCodesign2022 with board: Virtex-7 (XC7VX690T) {VC709} (HLS (Vitis)):
#             Score: 92.8% AP, Size: 0.09 MB, Latency: 1.6 ms, Throughput: 235 GOP/s, Power: 5.10 W
#     PennSyn2Real:
#         - SSD 0.25x (SSD) [VGG16] from suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 with board: Zynq US+ (XCZU3EG) {OVC3} (N/A):
#             Score: 76.2% mAP, Size: , Latency: , Throughput: 138 GOP/s, Power: 2.40 W
#         - SSD 0.5x (SSD) [VGG16] from suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 with board: Zynq US+ (XCZU3EG) {OVC3} (N/A):
#             Score: 83.9% mAP, Size: , Latency: , Throughput: 150 GOP/s, Power: 2.60 W
#         - SSD 1.0x (SSD) [VGG16] from suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 with board: Zynq US+ (XCZU3EG) {OVC3} (N/A):
#             Score: 88.4% mAP, Size: , Latency: , Throughput: 158 GOP/s, Power: 2.00 W
#     UAV RGB (cust.):
#         - YOLOv4 (YOLOv4) [Darknet53] from nguyenFPGASoCImplementationYOLOv42024 with board: Zynq US+ (XCZU7EV) {ZCU104} (Vitis AI (N/A)):
#             Score: 83.7% mAP, Size: 245 MB, Latency: 107.94 ms, Throughput: , Power: 30.1 W
#         - YOLOv4-tiny 3L (YOLOv4) [Darknet53-tiny] from nguyenFPGASoCImplementationYOLOv42024 with board: Zynq US+ (XCZU7EV) {ZCU104} (Vitis AI (N/A)):
#             Score: 72.24% mAP, Size: 24.10 MB, Latency: 19.18 ms, Throughput: , Power: 26.40 W
#         - AP2D-Net (CNN) [] from liNovelCNNBasedAP2DNet2020 with board: Zynq US+ (XCZU3EG) {Ultra96} (RTL design (N/A)):
#             Score: 55.0% mIoU, Size: , Latency: 32.8 ms, Throughput: 130.20 GOP/s, Power: 5.59 W
#     DIOR:
#         - YOLOv4-MobileNetv3 (YOLOv4) [MobileNetv3] from zhaoHardwareAccelerationSatellite2023a with board: Zynq US+ (XCK26) {KV260} (Vitis AI (v2.5)):
#             Score: 82.61% mAP, Size: 5.69 MB, Latency: , Throughput: , Power: 7.20 W
#         - RFA-YOLO (YOLOv4) [MobileNeXt] from liEdgeRealtimeObject2023a with board: Zynq US+ (XCZU7EV) {ZCU104} (Vitis AI (N/A)):
#             Score: 64.85% mAP, Size: 24.75 MB, Latency: , Throughput: , Power: 15.82 W
#     Airbus:
#         - ResNet-18+YOLOv2 (YOLOv2) [ResNet-18] from gargAircraftDetectionSatellite2024 with board: Zynq US+ (XCZU9EG) {ZCU102} (HLS (MATLAB)):
#             Score: 91% AP, Size: , Latency: , Throughput: , Power:
#     DAC 2018:
#         - CNN (CNN) [] from wangAccelerationImplementationConvolutional2019 with board: Zynq 7000 (XC7Z020) {PYNQ-Z1} (HLS (Vivado)):
#             Score: 21% mIoU, Size: , Latency: , Throughput: 69.80 GOP/s, Power: 2.38 W
#     NWPU VHR-10:
#         - CBFF-SSD (SSD) [MobileNetv1] from liEfficientObjectDetection2019a with board: Zynq 7000 (XC7Z100) {} (RTL design (Verilog)):
#             Score: 91.42% mAP, Size: , Latency: 42.59 ms, Throughput: 452.80 GOP/s, Power: 19.52 W
#     FastenerDataset (cust.):
#         - Improved YOLOv4-tiny (YOLOv4-tiny) [CSPDarknet53] from yuImprovedLightweightDeep2024 with board: Zynq US+ (XCZU7EV) {ZCU104} (Vitis AI (v1.4)):
#             Score: 95.1% mAP, Size: , Latency: , Throughput: , Power: 20.00 W
#     Google Earth Studio RGB (sim.):
#         - Improved YOLOv3 (YOLOv3) [DarkNet53] from wuDesignImplementationRemote2021 with board: Zynq US+ (XCZU9EG) {} (HLS (N/A)):
#             Score: 92% OA, Size: 8.50 MB, Latency: 7 ms, Throughput: , Power:
#     UAV RGB+MMW (cust.):
#         - Lightweight CNN (CNN) [ResNet-18] from wangFastDetectionObstacle2024 with board: Zynq 7000 (XC7Z020) {} (N/A):
#             Score: 70.1% mAP, Size: , Latency: , Throughput: , Power: 3.30 W
#     Total: 21
#
# Pixel classification task (total: 14):
#     University of Pavia:
#         - 2D CNN (CNN) [] from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#             Score: 98.24% OA, Size: 1.20 MB, Latency: 0.097 ms*, Throughput: 7.07 GOP/s, Power: 8.40 W
#         - 3D CNN (CNN) [] from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#             Score: 94.09% OA, Size: 0.12 MB, Latency: 1.11 ms*, Throughput: 3.81 GOP/s, Power: 8.40 W
#         - HybridSN (CNN) [] from heConfigurable2D3D2023a with board: Zynq US+ (XCZU15EG) {Alinx AXU15EG} (RTL design (N/A)):
#             Score: 100% OA, Size: 20.50 MB, Latency: 7.71 ms*, Throughput: 13.18 GOP/s, Power: 8.40 W
#         - LPDBL (ML) [] from shibiOnboardTargetDetection2021a with board: Virtex-7 (XC7VX690T) {} (RTL design (VHDL)):
#             Score: , Size: , Latency: , Throughput: , Power:
#         - SAM-GNN (GNN) [] from chellaswamyFPGAbasedRemoteTarget2024 with board: Virtex-7 (XC7VX690T) {} (RTL design (VHDL)):
#             Score: 95.05% OA, Size: , Latency: , Throughput: , Power:
#         - SVM (ML) [] from martinsRealtimeSVMbasedHardware2024 with board: Zynq 7000 (XC7Z020) {} (RTL design (VHDL)):
#             Score: 82.48% AA, Size: , Latency: 0.11 ms*, Throughput: , Power:
#     AVIRIS-NG:
#         - CAG-SC2S (ML) [] from gyaneshwarRealtimeSCSUP2022 with board: Artix-7 (XC7A35T) {Arty-35T} (RTL design (XSG)):
#             Score: 98.30% OA, Size: , Latency: 5.27 us*, Throughput: , Power: 0.31 W
#         - CAL-SC2S (ML) [] from gyaneshwarRealtimeSCSUP2022 with board: Artix-7 (XC7A35T) {Arty-35T} (RTL design (XSG)):
#             Score: 99.69% OA, Size: , Latency: 5.70 us*, Throughput: , Power: 0.36 W
#         - SVM (ML) [] from gyaneshwarRealtimeSCSUP2022 with board: Artix-7 (XC7A35T) {Arty-35T} (RTL design (XSG)):
#             Score: 20.71% OA, Size: , Latency: 5.12 us*, Throughput: , Power: 0.22 W
#     UAV RGB (cust.):
#         - Decision Tree (ML) [] from fraczekEmbeddedVisionSystem2018 with board: Zynq 7000 (XC7Z020) {Arty Z7} (RTL design (Verilog)):
#             Score: 92.1% OA, Size: , Latency: 300 ms*, Throughput: , Power: 3.50 W
#         - Weightless Neural Systems (WNS) [] from torresCombinedWeightlessNeural2020 with board: Zynq 7000 (XC7Z020) {} (N/A):
#             Score: 90.0% OA, Size: , Latency: , Throughput: , Power:
#     ALSAT-2A (cust.):
#         - BRAM_DSP (Fuzzy ARTMAP) [] from yahiaouiParallelizationFuzzyARTMAP2017a with board: Virtex-6 (XC6VLX240T) {} (RTL design (VHDL)):
#             Score: 94.8% OA, Size: , Latency: 21.28 us, Throughput: , Power: 4.8W
#         - LUT_MUL (Fuzzy ARTMAP) [] from yahiaouiParallelizationFuzzyARTMAP2017a with board: Virtex-6 (XC6VLX240T) {} (RTL design (VHDL)):
#             Score: 94.8% OA, Size: , Latency: 21.28 us, Throughput: , Power: 4.5W
#     Airport-Beach-Urban:
#         - Deep Belief Network (RBM) [] from boyleHighlevelFPGADesign2023a with board: Zynq US+ (XCZU7EV) {ZCU104} (HLS (Vitis)):
#             Score: , Size: , Latency: 5.4 ms, Throughput: , Power:
#     Total: 14
#
# Segmentation task (total: 6):
#     Potsdam:
#         - ENet (CNN) [] from sabogalMethodologyEvaluatingAnalyzing2021a with board: Zynq US+ (XCZU3EG) {UltraZed-EG} (Vitis AI (DNNDK)):
#             Score: 63.3% mIoU, Size: 0.36 MB, Latency: , Throughput: , Power: 3.36 W
#         - ESPNet (CNN) [] from sabogalMethodologyEvaluatingAnalyzing2021a with board: Zynq US+ (XCZU3EG) {UltraZed-EG} (Vitis AI (DNNDK)):
#             Score: 55.5% mIoU, Size: 0.33 MB, Latency: , Throughput: , Power: 3.08 W
#         - FPN (CNN) [] from sabogalMethodologyEvaluatingAnalyzing2021a with board: Zynq US+ (XCZU3EG) {UltraZed-EG} (Vitis AI (DNNDK)):
#             Score: 65.3% mIoU, Size: 5.84 MB, Latency: , Throughput: , Power: 4.03 W
#         - U-Net (CNN) [] from sabogalMethodologyEvaluatingAnalyzing2021a with board: Zynq US+ (XCZU3EG) {UltraZed-EG} (Vitis AI (DNNDK)):
#             Score: 61.4% mIoU, Size: 7.40 MB, Latency: , Throughput: , Power: 3.38 W
#     38-Cloud:
#         - C-FCN++ (CNN) [] from bahlLowpowerNeuralNetworks2019a with board: Cyclone V (5CSXC6) {} (HLS (VGT)):
#             Score: 79.30% mIoU, Size: 0.047 MB, Latency: 150 ms, Throughput: , Power:
#     Landsat-8-OLI (cust.):
#         - Roller Dung Bettle Clustering (ML) [] from ratnakumarHighSpeedRoller2021 with board: Virtex-6 (XC6VLX240T) {} (RTL design (Verilog)):
#             Score: 37.45% SSIM, Size: , Latency: 28.9 ms, Throughput: , Power: 0.12 W
#     Total: 6
#
# Regression task (total: 1):
#     SAR (sim.):
#         - MLP (MLP) [] from hammoudArtificialNeuralNetworksBased2022a with board: Zynq 7000 (XC7Z020) {PYNQ-Z1} (N/A):
#             Score: , Size: , Latency: , Throughput: , Power: 0.13 W
#     Total: 1

# %% [markdown]
# ## Analyze reporting: missing metrics

# %%
def is_undefined(item) -> bool:
    if isinstance(item, str):
        return item.startswith("N/A") or item.startswith("???") or item == ""
    elif isinstance(item, list):
        return all(is_undefined(subitem) for subitem in item)
    else:
        raise ValueError(f"Unsupported type: {type(item)}")
    
# ---  Quick check if any of the main information is missing ---
for index, article in datapointsDf.iterrows():
    if is_undefined(article["Model"]):
        print(f"Item N°{b}{index}{e} has no Model")
    if is_undefined(article["Dataset"]):
        print(f"Item N°{b}{index}{e} has no Dataset")
    if is_undefined(article["Board"]):
        print(f"Item N°{b}{index}{e} has no Board")
    if is_undefined(article["Task"]):
        print(f"Item N°{b}{index}{e} has no Task")

# %% [markdown]
# ### Check per article: Which article miss the most metrics
#
# #### First for the "performance" metrics

# %%
performanceMetrics: list[str] = [
    "Latency",
    "Task score",
    "Footprint",
    "Throughput",
    # "Frequency",
    "Complexity",
    "Power consumption",
]
# --- Compute the number of missing (performance) metrics for each model ---
# Add a column to the dataframe with the number of missing metrics
datapointsDf["Missing perf metrics"] = datapointsDf.apply(
    lambda article: sum(
        [
            is_undefined(article[metric])
            for metric in performanceMetrics
        ]
    ),
    axis=1,
)
print(f"{len(datapointsDf[datapointsDf['Missing perf metrics'] >= 1])}/{len(datapointsDf)}")
# Print average number of missing metrics
print(
    f"Average number of missing metrics: {datapointsDf['Missing perf metrics'].mean()}"
)

# --- Compute the number of missing (performance) metrics for each study ---
# Group by the citation key, aggregating the total missing metrics per study
missing_per_study = (
    datapointsDf
    .groupby("BBT Citation Key", as_index=False)["Missing perf metrics"].mean()
)
# Print the fraction of studies with any missing metrics
print(
    f"{len(missing_per_study[missing_per_study['Missing perf metrics'] >= 1])}"
    f"/{len(missing_per_study)} studies have missing metrics"
)
# Print the fraction of studies with any missing metrics
print(
    f"{len(missing_per_study[missing_per_study['Missing perf metrics'] >= 2])}"
    f"/{len(missing_per_study)} studies have more than 1 missing metrics"
)
# Print the fraction of studies with any missing metrics
print(
    f"{len(missing_per_study[missing_per_study['Missing perf metrics'] >= 3])}"
    f"/{len(missing_per_study)} studies have more than 2 missing metrics"
)
# Print the average number of missing metrics per study
print(
    f"Average number of missing metrics (per study): "
    f"{missing_per_study['Missing perf metrics'].mean()}"
)
# Out:
# 54/66
# Average number of missing metrics: 2.4393939393939394
# 41/46 studies have missing metrics
# 35/46 studies have more than 1 missing metrics
# 27/46 studies have more than 2 missing metrics
# Average number of missing metrics (per study): 2.75

# %% [markdown]
# #### Then for the "FPGA" metrics

# %%
FPGAMetrics: list[str] = [
    "Design",
    "Memory",
    "Precision",
    "Optimizations",
    "FPGA Util",
]
DPUMetrics: list[str] = [
    "Precision",
    "DPU Config",
    "DPU Core",
    "DPU Optimizations",
    "DPU Util",
]

# --- Compute the number of missing (fpga) metrics for each model ---
datapointsDf["Missing fpga metrics"] = datapointsDf.apply(
    lambda article: sum(
        [
            is_undefined(article[metric])
            for metric in FPGAMetrics
        ]
    ),
    axis=1,
)
datapointsDf["Missing dpu metrics"] = datapointsDf.apply(
    lambda article: sum(
        [
            is_undefined(article[metric])
            for metric in DPUMetrics
        ]
    ),
    axis=1,
)
# Print only the 'BBT Citation Key' and the missing metrics, only if there is more than 3 missing metrics
print_pretty_df(
    datapointsDf[
        ["BBT Citation Key", "Missing fpga metrics", "Missing dpu metrics"]
    ]
)
# Out:
# +----+-------------------------------------------------------+----------------------+---------------------+
# |    |                   BBT Citation Key                    | Missing fpga metrics | Missing dpu metrics |
# +----+-------------------------------------------------------+----------------------+---------------------+
# | 0  |          vitoloRealTimeOnboardSatellite2024           |          0           |          4          |
# | 1  |                 kimOnOrbitAICloud2024                 |          1           |          5          |
# | 2  |         nguyenFPGASoCImplementationYOLOv42024         |          4           |          3          |
# | 3  |         nguyenFPGASoCImplementationYOLOv42024         |          4           |          3          |
# | 4  |        yahiaouiParallelizationFuzzyARTMAP2017a        |          0           |          4          |
# | 5  |        yahiaouiParallelizationFuzzyARTMAP2017a        |          0           |          4          |
# | 6  |       weiFPGABasedHybridTypeImplementation2019        |          0           |          4          |
# | 7  |       weiFPGABasedHybridTypeImplementation2019        |          0           |          4          |
# | 8  |            fraczekEmbeddedVisionSystem2018            |          1           |          4          |
# | 9  |                heConfigurable2D3D2023a                |          0           |          4          |
# | 10 |                heConfigurable2D3D2023a                |          0           |          4          |
# | 11 |                heConfigurable2D3D2023a                |          0           |          4          |
# | 12 |       hammoudArtificialNeuralNetworksBased2022a       |          1           |          4          |
# | 13 |       matos-carvalhoStaticDynamicAlgorithms2019       |          1           |          4          |
# | 14 |          hashimotoShipClassificationSAR2019a          |          3           |          4          |
# | 15 |           shibiOnboardTargetDetection2021a            |          0           |          4          |
# | 16 |              liNovelCNNBasedAP2DNet2020               |          0           |          4          |
# | 17 |            bahlLowpowerNeuralNetworks2019a            |          2           |          4          |
# | 18 |             boyleHighlevelFPGADesign2023a             |          1           |          4          |
# | 19 |      chenHardwareImplementationConvolutional2020      |          1           |          4          |
# | 20 |        zhaoHardwareAccelerationSatellite2023a         |          3           |          3          |
# | 21 |         chellaswamyFPGAbasedRemoteTarget2024          |          0           |          4          |
# | 22 |         nerisFPGABasedImplementationCNN2022a          |          3           |          4          |
# | 23 |         nerisFPGABasedImplementationCNN2022a          |          3           |          4          |
# | 24 |         zhangFPGAImplementationCNNbased2021a          |          0           |          4          |
# | 25 |             wangFastDetectionObstacle2024             |          2           |          4          |
# | 26 |            liEfficientObjectDetection2019a            |          0           |          4          |
# | 27 |               liEdgeRealtimeObject2023a               |          4           |          3          |
# | 28 |            myojinDetectingUncertainBNN2020            |          2           |          4          |
# | 29 |           wuDesignImplementationRemote2021            |          1           |          4          |
# | 30 |       upadhyayDesignImplementationCNNbased2024        |          4           |          3          |
# | 31 |       upadhyayDesignImplementationCNNbased2024        |          4           |          3          |
# | 32 |          torresCombinedWeightlessNeural2020           |          3           |          4          |
# | 33 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |          0           |          4          |
# | 34 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |          0           |          4          |
# | 35 |       yanAutomaticDeploymentConvolutional2022a        |          0           |          4          |
# | 36 |       yanAutomaticDeploymentConvolutional2022a        |          0           |          4          |
# | 37 |             yuImprovedLightweightDeep2024             |          4           |          1          |
# | 38 |       rapuanoFPGAbasedHardwareAccelerator2021a        |          0           |          4          |
# | 39 |         zhangExtremelyPipelinedFPGAbased2023a         |          0           |          4          |
# | 40 |        ieracitanoExplainableEmbeddedNeural2024        |          1           |          4          |
# | 41 |       zhangEfficientFPGABasedImplementation2020       |          0           |          4          |
# | 42 |              huangEdgeTrustworthyAI2024               |          4           |          3          |
# | 43 |           yangAlgorithmHardwareCodesign2022           |          0           |          4          |
# | 44 |           yangAlgorithmHardwareCodesign2022           |          0           |          4          |
# | 45 |           yangAlgorithmHardwareCodesign2022           |          0           |          4          |
# | 46 |         niAlgorithmHardwareCoOptimization2023         |          0           |          4          |
# | 47 |         niAlgorithmHardwareCoOptimization2023         |          0           |          4          |
# | 48 |         niAlgorithmHardwareCoOptimization2023         |          0           |          4          |
# | 49 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |          0           |          4          |
# | 50 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |          0           |          4          |
# | 51 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |          1           |          4          |
# | 52 |         zhangAccurateLowlatencyEfficient2022a         |          0           |          4          |
# | 53 |          gargAircraftDetectionSatellite2024           |          2           |          4          |
# | 54 |    wangAccelerationImplementationConvolutional2019    |          0           |          4          |
# | 55 |           zhangAcceleratingGNNbasedSAR2023            |          0           |          4          |
# | 56 |              gyaneshwarRealtimeSCSUP2022              |          1           |          4          |
# | 57 |              gyaneshwarRealtimeSCSUP2022              |          1           |          4          |
# | 58 |              gyaneshwarRealtimeSCSUP2022              |          1           |          4          |
# | 59 |          martinsRealtimeSVMbasedHardware2024          |          0           |          4          |
# | 60 |      sabogalMethodologyEvaluatingAnalyzing2021a       |          3           |          1          |
# | 61 |      sabogalMethodologyEvaluatingAnalyzing2021a       |          3           |          1          |
# | 62 |      sabogalMethodologyEvaluatingAnalyzing2021a       |          3           |          1          |
# | 63 |      sabogalMethodologyEvaluatingAnalyzing2021a       |          3           |          1          |
# | 64 |          yangLightweightDetectionMethod2023           |          0           |          4          |
# | 65 |             ratnakumarHighSpeedRoller2021             |          1           |          5          |
# +----+-------------------------------------------------------+----------------------+---------------------+

# %% [markdown]
# ### Check per metric: Which metric are the less reported

# %%
allMetrics = performanceMetrics + FPGAMetrics + DPUMetrics
for metric in allMetrics:
    missing_metrics = 0
    for index, article in datapointsDf.iterrows():
        if is_undefined(article[metric]):
            missing_metrics += 1

    print(f"{r}{missing_metrics}{e} models miss the {b}{metric}{e} metric.")
# Out:
# 23 models miss the Latency metric.
# 6 models miss the Task score metric.
# 36 models miss the Footprint metric.
# 42 models miss the Throughput metric.
# 36 models miss the Complexity metric.
# 18 models miss the Power consumption metric.
# 17 models miss the Design metric.
# 17 models miss the Memory metric.
# 2 models miss the Precision metric.
# 26 models miss the Optimizations metric.
# 14 models miss the FPGA Util metric.
# 2 models miss the Precision metric.
# 56 models miss the DPU Config metric.
# 63 models miss the DPU Core metric.
# 61 models miss the DPU Optimizations metric.
# 62 models miss the DPU Util metric.
