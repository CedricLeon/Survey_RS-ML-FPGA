# %% [markdown]
# # Generate LaTeX code for RS/ML taxonomy table from a Dataframe
#
# Manually copying each entry from the dataframe to Overleaf was not very appealing as an afternoon activity. So, I decided to waste a few days trying to generate the LaTeX code for the tables/taxonomies from the Dataframe. Believe it or not, it worked out and the table generation is now fully automated. Yet, it's a tedious process and a lot of the decisions are hardcoded. See [table_fpga.py](table_FPGA.py) for the second taxonomy (Table 3).
# The only thing I added manually are `\hspace{}` to center the rotated text in large multirows. Indeed, it seems that the width of the rules of the `booktabs` package are not taken into account when centring the label.

# %%
import pandas as pd
from pathlib import Path
import re

from utils.utils import print_pretty_df, r, y, g, b, e
from utils.metadata import assign_model_core

from collections import OrderedDict


# Load the data
pickleName = "all_datapoints.pkl"
datapointsDfPath = Path("..") / "data" / "Dataframes" / pickleName
df = pd.read_pickle(datapointsDfPath)

# Path to save the latex table
latexPath = Path("../data/Tables/ML-RS_latex_table.tex")

# %%
print_pretty_df(df)
print(f"Total number of experiments: {len(df)}")
# Out:
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+
# |    |                   BBT Citation Key                    |             Model             | Equivalent model |    Backbone    |    Modality    |                      Dataset                      |         Task         |               Application               |                     Board                      |    Implementation    | Publication year |  Latency  |    FPS     | Task score  | Footprint |  Throughput  | Power consumption | Frequency  | Complexity  |               Design                |     Memory     |                Precision                |                        Optimizations                        |                 FPGA Util                 | DPU Config | DPU Core | DPU Util |  DPU Optimizations  |
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+
# | 0  |              huangEdgeTrustworthyAI2024               |             ETAUS             |       CNN        |   ResNet-50    |      HSI       |         UAV RGB (cust.) {Classification}          |    Classification    |         Air Quality Monitoring          |          Zynq US+ (XCZU19EG) {KV260}           |    Vitis AI (N/A)    |       2024       | 107.8 ms  |  9.3 FPS   |  86.38% F1  |           | 329.90 GOP/s |      1.65 W       | 106.25 MHz |             |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 1  |          martinsRealtimeSVMbasedHardware2024          |              SVM              |        ML        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |             Zynq 7000 (XC7Z020) {}             |  RTL design (VHDL)   |       2024       | 0.11 ms*  |            |  82.48% AA  |           |              |                   |  200 MHz   |             |           Model Specific            |    On-chip     |                Original                 |                       ['Unclear/Bad']                       |        Average (38% DSP, N/A BRAM)        |            |          |          |         []          |
# | 2  |             yuImprovedLightweightDeep2024             |     Improved YOLOv4-tiny      |   YOLOv4-tiny    | Darknet53-tiny |      RGB       |    FastenerDataset (cust.) {Object Detection}     |   Object detection   | Railway track fastener defect detection |          Zynq US+ (XCZU7EV) {ZCU104}           |   Vitis AI (v1.4)    |       2024       |           | 295.9 FPS  |  95.1% mAP  |           |              |      20.00 W      |  300 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |    2     |   N/A    |    ['UltraRAM']     |
# | 3  |                 kimOnOrbitAICloud2024                 |      TriCloudNet + U-Net      |       CNN        |   SqueezeNet   |      RGB       |        Landsat-8 (cust.) {Classification}         |    Classification    |             Cloud coverage              |          Zynq 7000 (XC7Z020) {ZC702}           |     HLS (Vivado)     |       2024       |  1028 ms  |  0.97 FPS  |  6.84% CRE  |  3.61 MB  |              |      0.196 W      |            |             |           Model Specific            |    Off-chip    |                   N/A                   |                      ['Multiple PEs']                       |     High (49% DSP, 60% BRAM, 70% LUT)     |            |          |          |         []          |
# | 4  |          vitoloRealTimeOnboardSatellite2024           |              CNN              |       CNN        |                |      RGB       |        Landsat-8 (cust.) {Classification}         |    Classification    |             Cloud coverage              |              Artix-7 (XC7A35T) {}              |  RTL design (VHDL)   |       2024       |           |            |  89.64% F1  |           |  1.14 GOP/s  |      0.116 W      |   36 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                Original                 |                      ['Multiple PEs']                       | Low (N/A DSP, N/A BRAM, 38% LUT, 15% FF)  |            |          |          |         []          |
# | 5  |         nguyenFPGASoCImplementationYOLOv42024         |            YOLOv4             |      YOLOv4      |   Darknet53    |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2024       | 107.94 ms |  17.9 FPS  |  83.7% mAP  |  245 MB   |              |      30.1 W       |  100 MHz   |  105.9G OP  |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 6  |         nguyenFPGASoCImplementationYOLOv42024         |        YOLOv4-tiny 3L         |      YOLOv4      | Darknet53-tiny |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |         Flying-object detection         |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2024       | 19.18 ms  |  125 FPS   | 72.24% mAP  | 24.10 MB  |              |      26.40 W      |  100 MHz   |  15.32G OP  |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |    N/A     |    2     |   N/A    |       ['N/A']       |
# | 7  |        yahiaouiParallelizationFuzzyARTMAP2017a        |           BRAM_DSP            |   Fuzzy ARTMAP   |                | RGB + infrared |      ALSAT-2A (cust.) {Pixel classification}      | Pixel classification |           Landcover/Land use            |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |       2017       | 21.28 us  |            |  94.8% OA   |           |              |       4.8 W       |  192 MHz   |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                      ['Multiple PEs']                       |          Low (91% DSP,52% BRAM)           |            |          |          |         []          |
# | 8  |        yahiaouiParallelizationFuzzyARTMAP2017a        |            LUT_MUL            |   Fuzzy ARTMAP   |                | RGB + infrared |      ALSAT-2A (cust.) {Pixel classification}      | Pixel classification |           Landcover/Land use            |            Virtex-6 (XC6VLX240T) {}            |  RTL design (VHDL)   |       2017       | 21.28 us  |            |  94.8% OA   |           |              |       4.5W        |  189 MHz   |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                      ['Multiple PEs']                       |           Low (0% DSP,0% BRAM)            |            |          |          |         []          |
# | 9  |       weiFPGABasedHybridTypeImplementation2019        |          LeNet-5 f32          |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |       2019       |  2.29 ms  |            |  98.76% OA  |  6.64 MB  |              |                   |  100 MHz   |             |           Various Kernels           |    Off-chip    |               Float (32)                |                      ['Multiple PEs']                       |        Average (34% DSP, 33% BRAM)        |            |          |          |         []          |
# | 10 |       weiFPGABasedHybridTypeImplementation2019        |          LeNet-5 i8           |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Kintex-7 (XC7K325T) {KC705}           |   RTL design (N/A)   |       2019       |  2.29 ms  |            |  97.77% OA  |  1.66 MB  |              |                   |  100 MHz   |             |           Various Kernels           |    Off-chip    |                Fixed (8)                |                      ['Multiple PEs']                       |          Low (14% DSP, 16% BRAM)          |            |          |          |         []          |
# | 11 |            fraczekEmbeddedVisionSystem2018            |         Decision Tree         |        ML        |                |      RGB       |      UAV RGB (cust.) {Pixel classification}       | Pixel classification |  Safe UAV landing site identification   |         Zynq 7000 (XC7Z020) {Arty Z7}          | RTL design (Verilog) |       2018       |  300 ms*  |            |  92.1% OA   |           |              |      3.50 W       |            |             |         Algorithm Specific          |    On-chip     |                Fixed (8)                |                           ['N/A']                           |          Low (10% DSP, 86% BRAM)          |            |          |          |         []          |
# | 12 |                heConfigurable2D3D2023a                |            2D CNN             |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 0.097 ms* |            |  98.24% OA  |  1.20 MB  |  7.07 GOP/s  |      8.40 W       |  100 MHz   |  0.684M OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |         Low (22.5% DSP, 71% BRAM)         |            |          |          |         []          |
# | 13 |                heConfigurable2D3D2023a                |            3D CNN             |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 1.11 ms*  |            |  94.09% OA  |  0.12 MB  |  3.81 GOP/s  |      8.40 W       |  100 MHz   |  4.231M OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |         Low (27.9% DSP, 76% BRAM)         |            |          |          |         []          |
# | 14 |                heConfigurable2D3D2023a                |           HybridSN            |       CNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |      Zynq US+ (XCZU15EG) {Alinx AXU15EG}       |   RTL design (N/A)   |       2023       | 7.71 ms*  |            |   100% OA   | 20.50 MB  | 13.18 GOP/s  |      8.40 W       |  100 MHz   | 101.642M OP |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |        Average (37% DSP, 80% BRAM)        |            |          |          |         []          |
# | 15 |       hammoudArtificialNeuralNetworksBased2022a       |              MLP              |       MLP        |                |      SAR       |              SAR (sim.) {Regression}              |      Regression      |      Oil spills feature extraction      |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         N/A          |       2022       |           |            |             |           |              |      0.13 W       |            |             | Model Specific (All layers on FPGA) |    On-chip     |                Original                 |                           ['N/A']                           |          Low (26% DSP, 1% BRAM)           |            |          |          |         []          |
# | 16 |       matos-carvalhoStaticDynamicAlgorithms2019       |              MLP              |       MLP        |                |      RGB       |         UAV RGB (cust.) {Classification}          |    Classification    |           Landcover/Land use            | Spartan-3A (XC3SD1800A) {Avnet Spartan-3A DSP} |  RTL design (VHDL)   |       2019       |           |            |  95.14% OA  |           |              |                   |            |             |         Algorithm Specific          |    On-chip     |      Mixed width (Fixed 32 and 8)       |                           ['N/A']                           |          Low (26% DSP, N/A BRAM)          |            |          |          |         []          |
# | 17 |          hashimotoShipClassificationSAR2019a          |              CNN              |       CNN        |                |      SAR       |          ALOS-2 (cust.) {Classification}          |    Classification    |           Ship identification           |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |         FINN         |       2019       |  330 ms   |            |   100% OA   |           |              |                   |            |             |                 N/A                 |    On-chip     |                 Binary                  |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 18 |           shibiOnboardTargetDetection2021a            |             LPDBL             |        ML        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |       2021       |           |            |             |           |              |                   |  200 MHz   |             |         Algorithm Specific          |    On-chip     |                Original                 |                      ['Multiple PEs']                       |          Low (14% DSP, 15% BRAM)          |            |          |          |         []          |
# | 19 |              liNovelCNNBasedAP2DNet2020               |           AP2D-Net            |       CNN        |                |      RGB       |        UAV RGB (cust.) {Object Detection}         |   Object detection   |                 Diverse                 |          Zynq US+ (XCZU3EG) {Ultra96}          |   RTL design (N/A)   |       2020       |  32.8 ms  | 30.53 FPS  | 55.0% mIoU  |           | 130.20 GOP/s |      5.59 W       |  300 MHz   |             |           Various Kernels           |    Off-chip    | Mixed (Fixed (1 to 24) weights (3) act) |                        ['SIMD MVU']                         |         High (80% DSP, 75% BRAM)          |            |          |          |         []          |
# | 20 |            bahlLowpowerNeuralNetworks2019a            |            C-FCN++            |       CNN        |                |      RGB       |              38-Cloud {Segmentation}              |     Segmentation     |             Cloud coverage              |             Cyclone V (5CSXC6) {}              |      HLS (VGT)       |       2019       |  150 ms   |   7 FPS    | 79.30% mIoU | 0.047 MB  |              |                   |  100 MHz   |   4.7K OP   | Model Specific (All layers on FPGA) |    On-chip     |               Fixed (16)                |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 21 |             boyleHighlevelFPGADesign2023a             |      Deep Belief Network      |       RBM        |                |      HSI       |    Airport-Beach-Urban {Pixel classification}     | Pixel classification |            Anomaly detection            |          Zynq US+ (XCZU7EV) {ZCU104}           |     HLS (Vitis)      |       2023       |  5.4 ms   |            |             |           |              |                   |  250 MHz   |             |         Algorithm Specific          |    On-chip     |               Float (32)                |                           ['N/A']                           |          Low (10% DSP, 0% BRAM)           |            |          |          |         []          |
# | 22 |      chenHardwareImplementationConvolutional2020      |            LeNet-5            |     LeNet-5      |    LeNet-5     |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |             Kintex-7 (XC7K325T) {}             |         N/A          |       2020       |  2.29 ms  |            |  98.18% OA  |           |              |                   |  100 MHz   |             |           Model Specific            |    Off-chip    |               Float (32)                |                           ['N/A']                           |          Low (N/A DSP, 33% BRAM)          |            |          |          |         []          |
# | 23 |        zhaoHardwareAccelerationSatellite2023a         |      YOLOv4-MobileNetv3       |      YOLOv4      |  MobileNetv3   |      RGB       |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |            Zynq US+ (XCK26) {KV260}            |   Vitis AI (v2.5)    |       2023       |           | 48.14 FPS  | 82.61% mAP  |  5.69 MB  |              |      7.20 W       |  200 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |        Average (59% DSP, N/A BRAM)        |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 24 |         chellaswamyFPGAbasedRemoteTarget2024          |            SAM-GNN            |       GNN        |                |      HSI       |    University of Pavia {Pixel classification}     | Pixel classification |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |  RTL design (VHDL)   |       2024       |           |            |  95.05% OA  |           |              |                   |  200 MHz   |             |         Algorithm Specific          |    Off-chip    |                Original                 |                      ['Multiple PEs']                       |          Low (13% DSP, 14% BRAM)          |            |          |          |         []          |
# | 25 |         nerisFPGABasedImplementationCNN2022a          |          AlexNetLite          |     AlexNet      |    AlexNet     |      RGB       |              MASATI {Classification}              |    Classification    |           Ship identification           |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |       2022       |           |            |   89% F1    |           |              |                   |  200 MHz   |  5.71G OP   |                 N/A                 |      N/A       |               Fixed (16)                |                           ['N/A']                           |          Low (31% DSP,39% BRAM)           |            |          |          |         []          |
# | 26 |         nerisFPGABasedImplementationCNN2022a          |        MobileNetv1Lite        |       CNN        |  MobileNetv1   |      RGB       |              MASATI {Classification}              |    Classification    |           Ship identification           |          Kintex US (XCKU040) {KCU105}          |     HLS (Vitis)      |       2022       |           |            |   94% F1    |           |              |                   |  200 MHz   |  0.05G OP   |                 N/A                 |      N/A       |               Fixed (16)                |                           ['N/A']                           |          Low (31% DSP,39% BRAM)           |            |          |          |         []          |
# | 27 |         zhangFPGAImplementationCNNbased2021a          |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z035) {}             |  RTL design (VHDL)   |       2021       |  3400 ms  |            | 67.32% mAP  |           | 111.50 GOP/s |      5.96 W       |  200 MHz   |   379G OP   |           Various Kernels           |    Off-chip    |      Mixed (Fixed 8 and Float 32)       |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (21% DSP, 74% BRAM)          |            |          |          |         []          |
# | 28 |             wangFastDetectionObstacle2024             |        Lightweight CNN        |       CNN        |   ResNet-18    |   RGB + MMW    |      UAV RGB+MMW (cust.) {Object Detection}       |   Object detection   |         UAV obstacles detection         |             Zynq 7000 (XC7Z020) {}             |         N/A          |       2024       |           |  60.0 FPS  |  70.1% mAP  |           |              |      3.30 W       |  100 MHz   |   4.6G OP   |                 N/A                 |    Off-chip    |                Fixed (8)                |                           ['N/A']                           |         High (70% DSP, 25% BRAM)          |            |          |          |         []          |
# | 29 |            liEfficientObjectDetection2019a            |           CBFF-SSD            |       SSD        |  MobileNetv1   |      RGB       |          NWPU VHR-10 {Object Detection}           |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z100) {}             | RTL design (Verilog) |       2019       | 42.59 ms  |            | 91.42% mAP  |           | 452.80 GOP/s |      19.52 W      |  200 MHz   |             |           Various Kernels           |    Off-chip    |               Fixed (16)                |            ['Advanced Dataflow', 'Multiple PEs']            |        Average (57% DSP, 60% BRAM)        |            |          |          |         []          |
# | 30 |               liEdgeRealtimeObject2023a               |           RFA-YOLO            |      YOLOv4      |   MobileNeXt   |      RGB       |              DIOR {Object Detection}              |   Object detection   |                 Diverse                 |          Zynq US+ (XCZU7EV) {ZCU104}           |    Vitis AI (N/A)    |       2023       |           | 27.97 FPS  | 64.85% mAP  | 24.75 MB  |              |      15.82 W      |  200 MHz   |             |                                     |                |                Fixed (8)                |                             []                              |                    N/A                    |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 31 |            myojinDetectingUncertainBNN2020            |              BNN              |       CNN        |                |      SAR       |          ALOS-2 (cust.) {Classification}          |    Classification    |           Ship identification           |          Zynq 7000 (XC7Z045) {ZC706}           |         FINN         |       2020       | 21.14 ms  |            |             |           |              |                   |            |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 32 |           wuDesignImplementationRemote2021            |        Improved YOLOv3        |      YOLOv3      |   DarkNet53    |      RGB       | Google Earth Studio RGB (sim.) {Object Detection} |   Object detection   |           Aircraft detection            |             Zynq US+ (XCZU9EG) {}              |      HLS (N/A)       |       2021       |   7 ms    |            |   92% OA    |  8.50 MB  |              |                   |            |             |           Various Kernels           |    Off-chip    |                Fixed (8)                |                      ['Multiple PEs']                       |                    N/A                    |            |          |          |         []          |
# | 33 |       upadhyayDesignImplementationCNNbased2024        |           ResNet-50           |       CNN        |   ResNet-50    |      RGB       |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |       2024       |  10.7 ms  | 93.02 FPS  |             |           |              |                   |            |             |                                     |                |                Fixed (8)                |                             []                              |                                           |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 34 |       upadhyayDesignImplementationCNNbased2024        |            SICNet             |       CNN        |                |      RGB       |           RGB (cust.) {Classification}            |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU9EG) {ZCU102}           |    Vitis AI (N/A)    |       2024       |  1.8 ms   | 530.66 FPS |  85.76% OA  |           |              |                   |            |             |                                     |                |                Fixed (8)                |                             []                              |                                           |   B4096    |   N/A    |   N/A    |       ['N/A']       |
# | 35 |          torresCombinedWeightlessNeural2020           |   Weightless Neural Systems   |       WNS        |                |      RGB       |      UAV RGB (cust.) {Pixel classification}       | Pixel classification |         Deforestation detection         |             Zynq 7000 (XC7Z020) {}             |         N/A          |       2020       |           |            |  90.0% OA   |           |              |                   |            |             |                 N/A                 |    On-chip     |                Original                 |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 36 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |       CloudSatNet-1 Q2        |       CNN        |                |      RGB       |             L8 Biome {Classification}             |    Classification    |             Cloud coverage              |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       2022       |           | 15.46 FPS  |  83.41% OA  |  1.43 MB  |              |      2.52 W       |  100 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                      ['Multiple PEs']                       |               Low (14% DSP)               |            |          |          |         []          |
# | 37 |  pitonakCloudSatNet1FPGABasedHardwareAccelerated2022  |       CloudSatNet-1 Q4        |       CNN        |                |      RGB       |             L8 Biome {Classification}             |    Classification    |             Cloud coverage              |          Zynq 7000 (XC7Z020) {Z-turn}          |         FINN         |       2022       |           | 15.47 FPS  |  87.42% OA  |  3.06 MB  |              |      2.59 W       |  100 MHz   |             | Model Specific (All layers on FPGA) |    On-chip     |                Fixed (4)                |                      ['Multiple PEs']                       |               Low (14% DSP)               |            |          |          |         []          |
# | 38 |       yanAutomaticDeploymentConvolutional2022a        |        Improved VGG16         |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |       2022       |  1780 ms  |            |  88.08% OA  | 14.80 MB  | 23.06 GOP/s  |      3.41 W       |  200 MHz   |  40.96G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (12% DSP, 29% BRAM)          |            |          |          |         []          |
# | 39 |       yanAutomaticDeploymentConvolutional2022a        |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |           Artix-7 (XC7A200T) {AC701}           |  RTL design (VHDL)   |       2022       | 17120 ms  |            | 67.30% mAP  | 49.40 MB  | 22.17 GOP/s  |      3.41 W       |  200 MHz   | 379.55G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (12% DSP, 29% BRAM)          |            |          |          |         []          |
# | 40 |       rapuanoFPGAbasedHardwareAccelerator2021a        |          CloudScout           |       CNN        |                |      HSI       |        Sentinel-2 (cust.) {Classification}        |    Classification    |             Cloud coverage              |          Zynq US+ (XCZU7EV) {ZCU106}           |  RTL design (VHDL)   |       2021       | 141.7 ms  |            |  92.0% OA   | 13.30 MB  |              |      3.40 W       | 115.4 MHz  |             |           Model Specific            |    Off-chip    |              Mixed (Fixed)              |            ['Advanced Dataflow', 'Multiple PEs']            |       High (67% DSP, 46% BRAM+URAM)       |            |          |          |         []          |
# | 41 |         zhangExtremelyPipelinedFPGAbased2023a         |             A2NN              |       CNN        |     VGG11      |      RGB       |        UC-Merced Land Use {Classification}        |    Classification    |           Landcover/Land use            |            Virtex-7 (XC7VX690T) {}             |   RTL design (N/A)   |       2023       |  4.92 ms  | 203.25 FPS |  94.76% OA  |           |  3047 GOP/s  |      8.27 W       |  200 MHz   |  14.99G OP  |           Model Specific            |    On-chip     |      Mixed (Fixed 4 and Float 32)       |                      ['Multiple PEs']                       |          Low (9% DSP, 86% BRAM)           |            |          |          |         []          |
# | 42 |        ieracitanoExplainableEmbeddedNeural2024        |          HO-ShipNet           |       CNN        |                |      RGB       |            Kaggle SSI {Classification}            |    Classification    |           Ship identification           |          Zynq 7000 (XC7Z045) {ZC706}           |  RTL design (VHDL)   |       2024       |  1.01 ms  |            |  93.44% F1  |           |              |      1.90 W       |            |             |           Model Specific            |    Off-chip    |               Fixed (16)                |                           ['N/A']                           |        Average (44% DSP, 44% BRAM)        |            |          |          |         []          |
# | 43 |       zhangEfficientFPGABasedImplementation2020       |            Q-IORN             |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          |  RTL design (VHDL)   |       2020       | 147.62 ms |  6.77 FPS  |  88.31% OA  | 121.51 MB | 209.60 GOP/s |      6.32 W       |  200 MHz   |             |           Model Specific            |    Off-chip    |                Fixed (8)                |            ['Advanced Dataflow', 'Multiple PEs']            |          Low (21% DSP, 27% BRAM)          |            |          |          |         []          |
# | 44 |           yangAlgorithmHardwareCodesign2022           |           CNN2@0.7            |      YOLOv2      |  MobileNetv1   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  0.7 ms   |  652 FPS   |   94% AP    |  0.09 MB  |  298 GOP/s   |      5.80 W       |  250 MHz   |  0.45G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (64% DSP,21% BRAM)         |            |          |          |         []          |
# | 45 |           yangAlgorithmHardwareCodesign2022           |           CNN4@0.7            |      YOLOv2      |  MobileNetv2   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  0.7 ms   |  636 FPS   |  93.3% AP   |  0.11 MB  |  366 GOP/s   |      6.60 W       |  250 MHz   |  0.56G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (69% DSP,21% BRAM)         |            |          |          |         []          |
# | 46 |           yangAlgorithmHardwareCodesign2022           |           CNN6@1.6            |      YOLOv2      |   SqueezeNet   |      SAR       |              SSDD {Object Detection}              |   Object detection   |             Ship detection              |          Virtex-7 (XC7VX690T) {VC709}          |     HLS (Vitis)      |       2022       |  1.6 ms   |  384 FPS   |  92.8% AP   |  0.09 MB  |  235 GOP/s   |      5.10 W       |  250 MHz   |   0.6G OP   | Model Specific (All layers on FPGA) |    On-chip     |           Mixed width (MPQAT)           | ['HW aware pruning', 'Multiple PEs', 'Pipeline scheduling'] |        Average (76% DSP,18% BRAM)         |            |          |          |         []          |
# | 47 |         niAlgorithmHardwareCoOptimization2023         |        Improved YOLOv2        |      YOLOv2      |   Darknet19    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       | 981.4 ms  |            | 67.30% mAP  | 49.40 MB  |  387 GOP/s   |      14.97 W      |  200 MHz   | 379.55G OP  |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 48 |         niAlgorithmHardwareCoOptimization2023         |           ResNet-34           |       CNN        |   ResNet-34    |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       |  40.2 ms  |            |  92.81% OA  | 21.29 MB  |  182 GOP/s   |      14.97 W      |  200 MHz   |  7.33G OP   |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 49 |         niAlgorithmHardwareCoOptimization2023         |             VGG16             |       CNN        |     VGG16      |      RGB       |          NWPU-RESISC45 {Classification}           |    Classification    |           Landcover/Land use            |          Virtex-7 (XC7VX690T) {VC709}          | RTL design (Verilog) |       2023       |  89.1 ms  |            |  91.90% OA  | 14.70 MB  |  344 GOP/s   |      14.97 W      |  200 MHz   |  30.69G OP  |           Various Kernels           |    Off-chip    |      Mixed width (Fixed 32 and 8)       |                      ['Multiple PEs']                       |          Low (23% DSP, 54% BRAM)          |            |          |          |         []          |
# | 50 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 0.25x           |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           | 34.18 FPS  |  76.2% mAP  |           |  138 GOP/s   |      2.40 W       |  200 MHz   |  4.04G OP   |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |            (73% DSP, 47% BRAM)            |            |          |          |         []          |
# | 51 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 0.5x            |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           |  9.6 FPS   |  83.9% mAP  |           |  150 GOP/s   |      2.60 W       |  200 MHz   |  15.65G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |         High (73% DSP, 55% BRAM)          |            |          |          |         []          |
# | 52 | suhAlgorithmHardwareCoOptimizationEnergyEfficient2021 |           SSD 1.0x            |       SSD        |     VGG16      |      RGB       |          PennSyn2Real {Object Detection}          |   Object detection   |         Flying-object detection         |           Zynq US+ (XCZU3EG) {OVC3}            |         N/A          |       2021       |           |  2.56 FPS  |  88.4% mAP  |           |  158 GOP/s   |      2.00 W       |  200 MHz   |  61.60G OP  |           Various Kernels           |    Off-chip    |                Fixed (8)                |       ['DSP double rate (like DPU)', 'Multiple PEs']        |                                           |            |          |          |         []          |
# | 53 |         zhangAccurateLowlatencyEfficient2022a         |              GNN              |       GNN        |                |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |          Zynq US+ (XCZU7EV) {ZCU104}           |      HLS (N/A)       |       2022       | 0.105 ms  |  9500 FPS  |  99.09% OA  |  0.96 MB  |              |      6.30 W       |  125 MHz   |  2.13M OP   |           Various Kernels           |    On-chip     |               Float (32)                |   ['Advanced Dataflow', 'Multiple PEs', 'PEs Pipelined']    |       High (74% DSP, 91% BRAM+URAM)       |            |          |          |         []          |
# | 54 |          gargAircraftDetectionSatellite2024           |       ResNet-18+YOLOv2        |      YOLOv2      |   ResNet-18    |      RGB       |             Airbus {Object Detection}             |   Object detection   |           Aircraft detection            |          Zynq US+ (XCZU9EG) {ZCU102}           |     HLS (MATLAB)     |       2024       |           |   46 FPS   |   91% AP    |           |              |                   |  250 MHz   |             |           Model Specific            |    Off-chip    |                Fixed (8)                |                           ['N/A']                           |                    N/A                    |            |          |          |         []          |
# | 55 |    wangAccelerationImplementationConvolutional2019    |              CNN              |       CNN        |                |      RGB       |            DAC 2018 {Object Detection}            |   Object detection   |                 Diverse                 |         Zynq 7000 (XC7Z020) {PYNQ-Z1}          |     HLS (Vivado)     |       2019       |           |   7 FPS    |  21% mIoU   |           | 69.80 GOP/s  |      2.38 W       |            |             | Model Specific (All layers on FPGA) |    On-chip     |                 Binary                  |                      ['Multiple PEs']                       |         Low (11% DSP, 100% BRAM)          |            |          |          |         []          |
# | 56 |           zhangAcceleratingGNNbasedSAR2023            |              GNN              |       GNN        |                |      SAR       |              MSTAR {Classification}               |    Classification    |     Military targets identification     |                Alveo (U280) {}                 |      HLS (N/A)       |       2023       |   27 ms   |  759 FPS   |             |           |  400 GOP/s   |      38.00 W      |  260 MHz   |             |           Various Kernels           | Off-chip (HBM) |                Original                 |         ['Multiple PEs', 'Other Kernel Splitting']          |        Average (43% DSP, 37% BRAM)        |            |          |          |         []          |
# | 57 |              gyaneshwarRealtimeSCSUP2022              |           CAG-SC2S            |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.27 us*  |            |  98.30% OA  |           |              |      0.31 W       | 70.40 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |         High (93% DSP, 21% BRAM))         |            |          |          |         []          |
# | 58 |              gyaneshwarRealtimeSCSUP2022              |           CAL-SC2S            |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.70 us*  |            |  99.69% OA  |           |              |      0.36 W       | 65.20 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |         High (96% DSP, 25% BRAM))         |            |          |          |         []          |
# | 59 |              gyaneshwarRealtimeSCSUP2022              |              SVM              |        ML        |                |      HSI       |         AVIRIS-NG {Pixel classification}          | Pixel classification |           Landcover/Land use            |          Artix-7 (XC7A35T) {Arty-35T}          |   RTL design (XSG)   |       2022       | 5.12 us*  |            |  20.71% OA  |           |              |      0.22 W       | 72.40 MHz  |             |           Model Specific            |      N/A       |               Fixed (32)                |              ['Systolic array', 'Unclear/Bad']              |        Average (49% DSP, 6% BRAM))        |            |          |          |         []          |
# | 60 |      sabogalMethodologyEvaluatingAnalyzing2021a       |             ENet              |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  25.2 FPS  | 63.3% mIoU  |  0.36 MB  |              |      3.36 W       |  300 MHz   |  4.06G OP   |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 61 |      sabogalMethodologyEvaluatingAnalyzing2021a       |            ESPNet             |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  11.7 FPS  | 55.5% mIoU  |  0.33 MB  |              |      3.08 W       |  300 MHz   |  3.71G OP   |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 62 |      sabogalMethodologyEvaluatingAnalyzing2021a       |              FPN              |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  14.1 FPS  | 65.3% mIoU  |  5.84 MB  |              |      4.03 W       |  300 MHz   |  17.30G OP  |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 63 |      sabogalMethodologyEvaluatingAnalyzing2021a       |             U-Net             |       CNN        |                |      RGB       |              Potsdam {Segmentation}               |     Segmentation     |               Urban areas               |        Zynq US+ (XCZU3EG) {UltraZed-EG}        |   Vitis AI (DNNDK)   |       2021       |           |  2.7 FPS   | 61.4% mIoU  |  7.40 MB  |              |      3.38 W       |  300 MHz   |  96.68G OP  |                                     |                |                Fixed (8)                |                             []                              |         High (70% DSP, 75% BRAM)          |   B1024    |   N/A    |  53.1%   | ['DSP double rate'] |
# | 64 |          yangLightweightDetectionMethod2023           |          Ghost-YOLOS          |      YOLOv3      |    GhostNet    |      RGB       |            DOTAv1.0 {Object Detection}            |   Object detection   |                 Diverse                 |             Zynq 7000 (XC7Z020) {}             | RTL design (Verilog) |       2023       |  320 ms   |            | 62.58% mAP  | 12.60 MB  | 29.53 GOP/s  |      2.98 W       |  150 MHz   |  8.41G OP   |           Model Specific            |    Off-chip    |               Fixed (16)                |               ['Multiple PEs', 'Unclear/Bad']               |        Average (58% DSP, 60% BRAM)        |            |          |          |         []          |
# | 65 |             ratnakumarHighSpeedRoller2021             | Roller Dung Bettle Clustering |        ML        |                |      RGB       |       Landsat-8-OLI (cust.) {Segmentation}        |     Segmentation     |                 General                 |            Virtex-6 (XC6VLX240T) {}            | RTL design (Verilog) |       2021       |  28.9 ms  |            | 37.45% SSIM |           |              |      0.12 W       | 230.52 MHz |   O(n) OP   |         Algorithm Specific          |    On-chip     |                   N/A                   |                    ['Advanced Dataflow']                    | Low (N/A DSP, 41% total slices, N/A BRAM) |            |          |          |         []          |
# +----+-------------------------------------------------------+-------------------------------+------------------+----------------+----------------+---------------------------------------------------+----------------------+-----------------------------------------+------------------------------------------------+----------------------+------------------+-----------+------------+-------------+-----------+--------------+-------------------+------------+-------------+-------------------------------------+----------------+-----------------------------------------+-------------------------------------------------------------+-------------------------------------------+------------+----------+----------+---------------------+
# Total number of experiments: 66

# %% [markdown]
# ### ML/RS Table generation
#
# This code generates the LaTeX code for the ML/RS table in the survey. It's basically divided in 2 parts: the preprocessing of the Dataframe to format, add citations, sort and group fields and the actual generation of the LaTeX code using some recursive tree structure.
#
# #### Data cleaning/preparation

# %%
# ---------------------------
# 1) Data cleaning and formatting
# ---------------------------

# ----- Rename columns -----
df = df.rename(
    columns={
        "BBT Citation Key": "Article",
        "Publication year": "Year",
        "Task score": "Score",
        "Power consumption": "Power",
    }
)

# ----- Rename Application values -----
def rename_application(app: str) -> str:
    if app == "Safe UAV landing site identification":
        return "UAV landing site id."
    elif app == "Railway track fastener defect detection":
        return "Railway defect det."
    elif app == "Redshift estimation [regression]":
        return "Redshift est."
    elif app == "Oil spills feature extraction":
        return "Oil spills mon."
    # elif app == "Air Quality Monitoring": # changed to "Air quality classification"
    #     return "Air quality mon."
    elif app == "Diverse":
        return "Diverse det."
    app = app.replace("identification", "id.")
    app = app.replace("detection", "det.")
    app = app.replace("classification", "class.")
    app = app.replace("extraction", "extr.")
    return app
df["Application"] = df["Application"].apply(rename_application)
# print(df["Application"].unique())


# ----- Clean up the Dataset column -----
# Remove the task from the dataset tag
def remove_task_from_dataset_tag(datasetTag: str) -> str:
    return datasetTag.split("{")[0].strip()

df["Dataset"] = df["Dataset"].apply(remove_task_from_dataset_tag)
# Rename long dataset names + add citations
with_citation = True
def wrap_italic(x):
    return r"\textit{" + x + r"}"
dataset_order = {
    "UC-Merced Land Use": "UCM Land Use"
    + r" \cite{yangBagvisualwordsSpatialExtensions2010}"
    if with_citation
    else "",
    "NWPU-RESISC45": "NWPU-RESISC45" + r" \cite{chengRemoteSensingImage2017}"
    if with_citation
    else "",
    "MASATI": "MASATI" + r" \cite{gallegoAutomaticShipClassification2018}"
    if with_citation
    else "",
    "Kaggle SSI": "Kaggle SSI",
    "L8 Biome": "L8 Biome" + r" \cite{fogaCloudDetectionAlgorithm2017}"
    if with_citation
    else "",
    "MSTAR": "MSTAR" + r" \cite{MSTAROverview}" if with_citation else "",
    "University of Pavia": r"University of Pavia"
    + r" \cite{HyperspectralRemoteSensing}"
    if with_citation
    else "",
    "AVIRIS-NG": "AVIRIS-NG",
    "Airport-Beach-Urban": "ABU" + r" \cite{ABUDataset}" if with_citation else "",
    "Potsdam": "Potsdam" + r" \cite{2DSemanticLabeling}" if with_citation else "",
    "38-Cloud": "38-Cloud"
    + r" \cite{mohajeraniSorourMo38CloudCloudSegmentationDataset2024}"
    if with_citation
    else "",
    "DOTAv1.0": "DOTAv1.0" + r" \cite{xiaDOTALargeScaleDataset2018}"
    if with_citation
    else "",
    "DIOR": "DIOR" + r" \cite{liObjectDetectionOptical2020}" if with_citation else "",
    "NWPU VHR-10": "NWPU VHR-10" + r" \cite{chengMulticlassGeospatialObject2014}"
    if with_citation
    else "",
    "DAC 2018": "DAC 2018",
    "PennSyn2Real": "PennSyn2Real" + r" \cite{nguyenPennSyn2RealTrainingObject2021}"
    if with_citation
    else "",
    "Airbus": "Airbus",
    "SSDD": "SSDD" + r" \cite{liShipDetectionSAR2017}" if with_citation else "",
    "Sentinel-2 (cust.)": wrap_italic("Sentinel-2 (cust.)"),
    "Landsat-8-OLI (cust.)": wrap_italic("Landsat-8-OLI (cust.)"),
    "ALOS-2 (cust.)": wrap_italic("ALOS-2 (cust.)"),
    "ALSAT-2A (cust.)": wrap_italic("ALSAT-2A (cust.)"),
    "FastenerDataset (cust.)": wrap_italic("FastenerDataset (cust.)"),
    "RGB (cust.)": wrap_italic("RGB (cust.)"),
    "UAV RGB (cust.)": wrap_italic("UAV RGB (cust.)"),
    "UAV RGB+MMW (cust.)": wrap_italic("UAV RGB+MMW (cust.)"),
    "SAR (sim.)": wrap_italic("SAR (sim.)"),
    "1D Signal (sim.)": wrap_italic("1D Signal (sim.)"),
    "Google Earth Studio RGB (sim.)": wrap_italic("GES RGB (sim.)"),
}
df.replace({"Dataset": dataset_order}, inplace=True)

# ----- Wrap citation keys with the command -----
if not df["Article"][0].startswith(r"\cite"):
    df["Article"] = df["Article"].apply(lambda x: f"\\cite{{{x}}}")

# ----- Clean up "Board" names -----
def determine_board(boardTag: str) -> str:
    family = boardTag.split("(")[0].strip()
    return family
df["Board"] = df["Board"].apply(determine_board)

# ----- Backslash math chararacters in Model names-----
df["Model"] = df["Model"].apply(lambda x: x.replace("_", r"\_"))

#  ----- Adjust metrics units -----
def transform_score(score_val: str) -> str:
    m = re.search(r"([\d.]+)%\s*(\S+)", score_val)
    if not m:
        return score_val
    num_part, metric_part = m.groups()
    return f"{num_part} ({metric_part})"
df["Score"] = df["Score"].fillna("").apply(transform_score)

def transform_complexity(val: str) -> str:
    return val.replace(" OP", "")
df["Complexity"] = df["Complexity"].fillna("").apply(transform_complexity)

def strip_unit(val: str) -> str:
    return re.sub(r"\s*(MB|W|GOP/s)$", "", val)
df["Footprint"] = df["Footprint"].fillna("").apply(strip_unit)
df["Throughput"] = df["Throughput"].fillna("").apply(strip_unit)
df["Power"] = df["Power"].fillna("").apply(strip_unit)

# ----- Simplify modalities -----, e.g., "RGB + infrared" -> "RGB"
def simplify_modality(modalityTag: str) -> str:
    return modalityTag.split("+")[0].strip()
df["Modality"] = df["Modality"].apply(simplify_modality)

# ----- Add the model core -----
df["Model Core"] = df.apply(assign_model_core, axis=1)

# Acronym for long model names
df["Model"] = df["Model"].replace("Roller Dung Bettle Clustering", "RDBC")
df["Model"] = df["Model"].replace("Weightless Neural System", "WNS")

# ---------------------------
# 2) Sorting the data
# ---------------------------
taskOrder = [
    "Classification",
    "Segmentation - Pixel", # previously named "Pixel classification",
    "Segmentation - Tile",  # previously named "Segmentation",
    "Object detection",
    "Regression",
]
modalityOrder = ["RGB", "RGB + infrared", "RGB + MMW", "HSI", "SAR", "1D"]
app_order = [
    "Deforestation det.",
    "UAV landing site id.",
    "Land Use Land Cover",
    "Military targets id.",
    "Ship id.",
    "Urban areas",
    "Cloud coverage class.",
    "Cloud coverage extr.",
    # "General", # changed to "Land Use Land Cover"
    "Redshift est.",
    "Air quality class.",
    "Oil spills mon.",
    "Diverse det.",
    "Flying-object det.",
    "Aircraft det.",
    "UAV obstacles det.",
    "Railway defect det.",
    "Anomaly det.",
    "Ship det.",
]

# Build a custom order_map, create new columns
task_order_map = {val: idx for idx, val in enumerate(taskOrder)}
df["TaskSortKey"] = df["Task"].map(task_order_map)
modality_order_map = {val: idx for idx, val in enumerate(modalityOrder)}
df["ModalitySortKey"] = df["Modality"].map(modality_order_map)
app_order_map = {val: idx for idx, val in enumerate(app_order)}
df["AppSortKey"] = df["Application"].map(app_order_map)
app_order_map = {val: idx for idx, val in enumerate(dataset_order.values())}
df["DatasetSortKey"] = df["Dataset"].map(app_order_map)

# Sort by the new columns
df = df.sort_values(
    by=["TaskSortKey", "ModalitySortKey", "AppSortKey", "DatasetSortKey"]
)
# print_pretty_df(
#     df[
#         [
#             "Task",
#             "TaskSortKey",
#             "Modality",
#             "ModalitySortKey",
#             "AppSortKey",
#             "Application",
#             "DatasetSortKey",
#             "Dataset",
#         ]
#     ]
# )

# Drop the sort keys
df.drop(
    columns=["TaskSortKey", "ModalitySortKey", "AppSortKey", "DatasetSortKey"],
    inplace=True,
)

# %% [markdown]
# ### Recursive mechanics

# %%
def check_array(tags, tdict):
    name = []
    for k, ids in tdict.items():
        for v in ids:
            if v in list(tags)[0]:
                name.append(k)
    if name == []:
        return list(tdict)[-1]
    else:
        return ",".join(name)


class TexNode:
    def __init__(self, name, df, columns, i, sdepth):
        self.name = name
        self.max_depth = len(columns)
        self.nodes = []
        self.depth = i
        self.len = df.shape[0]
        if i > 0:
            self.hook = columns[i - 1].hook
            self.cwidth = columns[i - 1].cwidth

        if i < len(columns):
            self.column = columns[i]
            self.final = False
            if self.column.array:
                for j in range(len(df)):
                    r = df.iloc[[j]]
                    name = check_array(r[self.column.df_key], self.column.tags)
                    self.nodes.append(TexNode(name, r, columns, i + 1, 4))
            else:
                a = 0
                unique_vals = df[self.column.df_key].unique()
                for val in unique_vals:
                    rows = df.loc[df[self.column.df_key] == val]
                    if len(rows) == 0:
                        continue
                    if self.depth >= sdepth:
                        for j in range(len(rows)):
                            self.nodes.append(
                                TexNode(val, rows.iloc[[j]], columns, i + 1, 4)
                            )
                    else:
                        self.nodes.append(TexNode(val, rows, columns, i + 1, 4))
                    a += len(rows)
                if a != self.len:
                    print("ERROR not all rows classified " + self.column.df_key)
                    print(f"Total rows {self.len} used {a}")
                    print(df[self.column.df_key])
                    for tar in df[self.column.df_key].unique():
                        found = 0
                        for k, v in self.column.tags.items():
                            if tar in v:
                                found = 1
                                break
                        if found == 0:
                            print("Missed key " + tar)
        else:
            self.column = None
            self.final = True

    def render(self, text_in, first, last, max_depth):
        text = text_in
        if first:
            text += "".join(["    " for x in range(self.depth - 2)])
        else:
            text += "".join(["   &" for x in range(self.depth - 2)])
        if self.depth > 1:
            text += "   &"
        if self.name == "":
            self.name = "-"
        if self.hook is None:
            text += f"\\multirow{{{self.len}}}{{*}}{{{self.name}}}"
        else:
            text += f"\\multirow{{{self.len}}}{{*}}{{{self.hook(self.name)}}}"
        if self.final:
            text += "\\\\\n"
            for i in range(self.len - 1):
                text += "".join(["   &" for x in range(self.depth - 1)]) + "\\\\\n"
        else:
            text += "\n"
            for n in self.nodes:
                text = n.render(
                    text, (n == self.nodes[0]), (n == self.nodes[-1]), max_depth
                )
        if self.depth <= max_depth:
            if not last:
                text += f"\\cmidrule{{{self.depth}-{self.max_depth}}}\n"
        return text


class TexTable:
    def __init__(self, df, columns):
        self.data = df
        self.columns = columns
        self.start = TexNode("Start", df, columns, 0, 4)

    def render(self, text_in, max_depth):
        self.text = text_in
        self.text += self.header()
        for n in self.start.nodes:
            self.text = n.render(
                self.text,
                (n == self.start.nodes[0]),
                (n == self.start.nodes[-1]),
                max_depth,
            )
        self.text += self.footer()
        return self.text

    def header(self):
        text = "\\begin{table}\n\\centering\n"
        text += r"""
\newcolumntype{H}{>{\setbox0=\hbox\bgroup}c<{\egroup}@{}}

\caption{RS/ML Taxonomy Table}
\label{table:rs-ml_taxonomy}

\begin{adjustbox}{totalheight=\textheight-2\baselineskip}
"""
        text += "\\begin{tabular}{"
        text += "".join(
            ["H" if (c.name == "Eq. Model") else "c" for c in self.columns]
        )  # Hide the Eq. Model column
        text += "}\n"
        # Write the header categories
        text += r"""
\multicolumn{1}{c}{\textbf{CV}} & \multicolumn{3}{c}{\textbf{Remote Sensing}} & \multicolumn{2}{c}{\textbf{Article}} & \multicolumn{4}{c}{\textbf{ML Model}} & \multicolumn{1}{c}{\textbf{FPGA}} &\multicolumn{3}{c}{\textbf{Performance}}\\
\cmidrule(lr){1-1} \cmidrule(lr){2-4} \cmidrule(lr){5-6} \cmidrule(lr){7-10} \cmidrule(lr){11-11} \cmidrule(lr){12-14}
"""
        # Write the header row
        for c in self.columns:
            text += f"\\textbf{{{c.name}}}"
            if c != self.columns[-1]:
                text += " &"
        text += "\\\\\n \\toprule \n"
        return text

    def footer(self):
        text = r"""
\bottomrule
\multicolumn{14}{c}{
\textit{Task:} \textbf{Regr.} Regression; \textit{Dataset:} \textbf{GES} Google Earth Studio, \textbf{MMW} MilliMeter-Wave radar; \textit{Model:} \textbf{RDBC} Roller Dung Bettle Clustering, \textbf{WNS} Weightless Neural System
}
\end{tabular}
\end{adjustbox}
\end{table}
"""
        return text


class TexColumn:
    def __init__(
        self,
        df_key: str,
        tags: dict,
        name: str,
        cwidth: str = "4em",
        array=False,
        hook=None,
    ):
        self.df_key = df_key
        self.tags = tags
        self.name = name
        self.cwidth = cwidth
        self.hook = hook
        self.array = array

# %%
# ---------------------------
# 3) Prepare dictionaries for the TexColumn tags
#    Each dictionary key will be how you group the data, with a list of possible values.
#    For brevity, we build them from the actual data in df.
# ---------------------------
def build_tag_dict_from_column(column_values):
    """
    Build an OrderedDict so the iteration order matches the sorted DataFrame order.
    """
    unique_values = list(pd.unique(column_values))
    # This preserves the exact order in which values appear, otherwise we override the sorting
    tag_dict = OrderedDict((val, [val]) for val in unique_values)
    return tag_dict


task_tags = build_tag_dict_from_column(df["Task"])
modality_tags = build_tag_dict_from_column(df["Modality"])
application_tags = build_tag_dict_from_column(df["Application"])
dataset_tags = build_tag_dict_from_column(df["Dataset"])
article_tags = build_tag_dict_from_column(df["Article"])
year_tags = build_tag_dict_from_column(df["Year"])
board_tags = build_tag_dict_from_column(df["Board"])
model_tags = build_tag_dict_from_column(df["Model"])
core_tags = build_tag_dict_from_column(df["Model Core"])
backbone_tags = build_tag_dict_from_column(df["Backbone"])
equivmodel_tags = build_tag_dict_from_column(df["Equivalent model"])
score_tags = build_tag_dict_from_column(df["Score"])
footprint_tags = build_tag_dict_from_column(df["Footprint"])
complex_tags = build_tag_dict_from_column(df["Complexity"])
# latency_tags    = build_tag_dict_from_column(df["Latency"])
# through_tags    = build_tag_dict_from_column(df["Throughput"])
# power_tags      = build_tag_dict_from_column(df["Power"])


# ---------------------------
# 4) Build the TexColumns array for each column we want to show
#    Each TexColumn references the .df_key and uses the dictionary we built.
# ---------------------------
columns = [
    TexColumn(
        "Task",
        task_tags,
        "Task",
        "2.5em",
        hook=lambda x: f"\\rotatebox[origin=c]{{90}}{{{x}}}",
    ),
    TexColumn("Modality", modality_tags, "Mod.", "2.5em"),
    TexColumn("Application", application_tags, "Application", "2.5em"),
    TexColumn("Dataset", dataset_tags, "Dataset", "3em"),
    TexColumn("Article", article_tags, "Ref.", "2em"),
    TexColumn("Year", year_tags, "Year", "1.5em"),
    TexColumn("Model", model_tags, "Original Name", "2.5em"),
    TexColumn("Model Core", core_tags, "Core", "2em"),
    TexColumn("Backbone", backbone_tags, "Backbone", "2em"),
    TexColumn("Equivalent model", equivmodel_tags, "Eq. Model", "2em"),
    TexColumn("Board", board_tags, "Family", "2.5em"),
    TexColumn("Score", score_tags, r"Score [\%]", "2em"),
    TexColumn("Footprint", footprint_tags, "MF[MB]", "2em"),
    TexColumn("Complexity", complex_tags, "C[OP]", "2em"),
    # TexColumn("Latency", latency_tags, "Latency [ms]", "2em"),
    # TexColumn("Throughput", through_tags, "Throughput [GOP/s]", "2em"),
    # TexColumn("Power", power_tags, "Power [W]", "2em"),
]

# ---------------------------
# 5) Create the table
tex_table = TexTable(df, columns)
latex_text = tex_table.render("", max_depth=4)

# ---------------------------
# 6) Last minute changes
# Don't rotate Regression (it's only on one line), use a manual footnote instead
latex_text = re.sub(
    r"\\rotatebox\[origin=c\]\{90\}\{Regression\}", r"Regr.", latex_text
)

# ----- Save to file -----
latexPath.parent.mkdir(parents=True, exist_ok=True)
with open(latexPath, "w") as f:
    f.write(latex_text)
print(f"{g}LaTeX table saved to {latexPath}{e}")
# Out:
# LaTeX table saved to ..\data\Tables\ML-RS_latex_table.tex

# %% [markdown]
# #### A little bit more statistics

# %%
nb_classif = len(df[df["Task"] == ("Classification")])
nb_seg_pixel = len(df[df["Task"] == ("Segmentation - Pixel")])
nb_seg_tile = len(df[df["Task"] == ("Segmentation - Tile")])
nb_obj_det = len(df[df["Task"] == ("Object detection")])
print(
    f"{nb_classif} datapoints formulated as classsification or {nb_classif / len(df) * 100:.2f}%"
)
print(
    f"{nb_seg_pixel} datapoints formulated as segmentation (pixel) or {nb_seg_pixel / len(df) * 100:.2f}%"
)
print(
    f"{nb_seg_tile} datapoints formulated as segmentation (tile) or {nb_seg_tile / len(df) * 100:.2f}%"
)
print(
    f"{nb_obj_det} datapoints formulated as object detection or {nb_obj_det / len(df) * 100:.2f}%"
)


# Print number of model consuming more than 5W
consumption = list(df["Power"])
# Remove empty values
consumption = [x for x in consumption if x != ""]
# Remove the ' W' suffix
consumption = [x.replace(" W", "") for x in consumption]
consumption = [float(x.replace("W", "")) for x in consumption]
print(
    f"{len(consumption)} experiments report power consumption, average: {sum(consumption) / len(consumption):.2f}W"
)
print(f"{len([x for x in consumption if x > 5])} models consume more than 5W")
# Out:
# 24 datapoints formulated as classsification or 36.36%
# 14 datapoints formulated as pixel classification or 21.21%
# 6 datapoints formulated as segmentation or 9.09%
# 21 datapoints formulated as object detection or 31.82%
# 48 experiments report power consumption, average: 7.08W
# 21 models consume more than 5W
